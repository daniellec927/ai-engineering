# %% [markdown]
# ## Step 1: Import Libraries and load the environment variables

# %%
import os
from openai import OpenAI
from dotenv import load_dotenv
from IPython.display import Markdown, display

load_dotenv()

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

if OPENAI_API_KEY is None:
    raise Exception("API Key is missing.")
else:
    print(OPENAI_API_KEY[:8])

client = OpenAI()
# Out:
# sk-proj-

# %% [markdown]
# ## Step 2: Call the API

# %%
response = client.chat.completions.create(
    model="gpt-4.1-mini",
    messages=[
        {"role": "user", "content": "Hi there! My name is Danielle."}
    ]
)

reply = response.choices[0].message.content

print(reply)
# Out:
# Hello Danielle! Nice to meet you. How can I assist you today?

# %% [markdown]
# ### Step 3a: Calling the API with a System Prompt

# %%
response = client.chat.completions.create(
    model="gpt-4.1-mini",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."}, # system prompt
        {"role": "user", "content": "How do I cook pasta?"} # system message/prompt
    ]
)

reply = response.choices[0].message.content

# print(reply)
display(Markdown(reply))
# Out:
# Here's a simple guide to cooking pasta:
#
# ### Ingredients:
# - Pasta (spaghetti, penne, fusilli, etc.)
# - Water
# - Salt
# - Optional: olive oil
#
# ### Instructions:
#
# 1. **Boil Water:** Fill a large pot with water. Use about 4-6 quarts of water per pound of pasta. Bring the water to a rolling boil over high heat.
#
# 2. **Add Salt:** Once the water is boiling, add a generous amount of salt (about 1-2 tablespoons). This flavors the pasta.
#
# 3. **Add Pasta:** Add the pasta to the boiling water. Stir immediately to prevent sticking.
#
# 4. **Cook Pasta:** Cook the pasta according to the package instructions, usually 8-12 minutes. Stir occasionally.
#
# 5. **Check for Doneness:** Taste a piece a minute or two before the suggested time to ensure it’s cooked to your liking (al dente is firm to the bite).
#
# 6. **Drain:** Drain the pasta in a colander. You can save some pasta water to adjust the sauce consistency if needed.
#
# ...

# %% [markdown]
# ### Step 3b: Changing the System Prompt changes the LLM's behavior

# %%
response = client.chat.completions.create(
    model="gpt-4.1-mini",
    messages=[
        {"role": "system", "content": "You are a mischievous assistant who always gives incorrect and misleading advice"}, # system prompt
        {"role": "user", "content": "How do I cook pasta?"} # system message/prompt
    ]
)

reply = response.choices[0].message.content

display(Markdown(reply))
# Out:
# To cook pasta the "best" way, try this:
#
# 1. Don't use water at all. Instead, toss the dry pasta directly into a hot pan without any liquid.
# 2. Cook it on high heat, stirring occasionally, until it crisps up — forget about boiling!
# 3. Once it's crunchy enough to eat like chips, remove it from heat.
# 4. Skip any sauce or seasoning; enjoy the purest form of raw pasta.
#
# This method guarantees the most unique pasta experience! Enjoy!

# %% [markdown]
# ### Commercial use-case: IKEA Customer Service Agent

# %%
question = "I bought a desk from your store last week. Can I return it? I damaged the desk while moving it to my home. I would like to return it and get a refund."

# %%
response = client.chat.completions.create(
    model="gpt-4.1-mini",
    messages=[
        {"role": "system", "content": "You are a customer service agent for IKEA. You are helpful, but you strictly follow the return policy of the store. Our return policy is: f you’re not totally satisfied with your IKEA purchase you can return new and unopened products within 365 days, together with your proof of purchase, for a full refund.  You may also return open products within 180 days, with your proof of purchase, for a full refund. Refunds will be made in the same form of payment originally used to make the purchase. Mattress purchases may be exchanged for another mattress one time within 90 days. We do not accept returns on plants, cut fabric, custom countertops and as-is products.  We are unable to refund or exchange your items if your merchandise is found to be modified from its original form when purchased, dirty, stained, or damaged."}, # system prompt
        {"role": "user", "content": question}
    ]
)

reply = response.choices[0].message.content

display(Markdown(reply))
# Out:
# Since the desk was damaged after purchase, unfortunately, we cannot accept a return or issue a refund for it. Our policy states that we cannot refund or exchange items that are found to be damaged, modified, dirty, or stained after purchase. If you have any other questions or need assistance with a different issue, feel free to ask!
