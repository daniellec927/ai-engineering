# %% [markdown]
# ## Step 1: Import Libraries & API Keys

# %%
import os
from openai import OpenAI
from dotenv import load_dotenv
from IPython.display import Markdown, display
import gradio as gr
import json
import requests

load_dotenv()

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

if OPENAI_API_KEY is None:
    raise Exception("API key is missing")

client = OpenAI(api_key=OPENAI_API_KEY)

# %% [markdown]
# ## Step 2: Load the document(s)

# %%
# netflix culture memo
document = """
The Best Work of Our Lives
CULTURE MEMO
At Netflix, we aspire to entertain the world, thrilling audiences everywhere. To do that, we’ve
developed an unusual company culture focused on excellence, and creating an environment
where talented people can thrive — lifting ourselves, each other and our audiences higher and
higher. This document is about that culture, which is based on four core principles:
● The Dream Team: We aim only to have high performers at Netflix — people who are
great at what they do, and even better at working together.
● People over Process: You get better outcomes when employees have the information
and freedom to make decisions for themselves. We hire unusually responsible people
who thrive on this openness and freedom.
● Uncomfortably Exciting: To entertain the world, we need to be bold and ambitious.
That means embracing the thrill of what’s next — even when it’s uncomfortable.
● Great and Always Better: We often say Netflix sucks today compared to where we can
be tomorrow. We need the self-awareness to understand what should be better, and
the discipline and resilience to get there.
While we don’t always live up to these principles, most people who join Netflix are pleasantly
surprised by how great their colleagues are and the way we empower people at every level.
As our business grows and evolves, our culture (and this document) will, too. What won’t
change is our focus on excellence, and our determination to ensure that Netflix remains a
place where great people can do the best work of their lives. If this sounds exciting, you’ll
probably love it here. But Netflix is not for everyone, so please read on.
THE DREAM TEAM
We believe that what makes a fantastic workplace isn’t a great office or free meals and
massages — although we have some nice perks. It’s the people. Imagine working alongside
stunning colleagues who are great at what they do, and even better at working together. It’s
why we model ourselves on a professional sports team, not a family. Families are about
unconditional love. They can also be dysfunctional, as anyone who’s watched Ozark or
Wednesday knows. Professional sports teams, on the other hand, focus on performance and
picking the right person for every position, even when that means swapping out someone
they love for a better player.
While every member of our Dream Team has different skills, we look for common strengths
that make us better together. These are the values we value:
● Selflessness — you are humble when searching for the best ideas; you seek what’s
best for Netflix, not yourself or your team; you take time to help others succeed.
● Judgment — you look beyond short term fixes in favor of long term solutions; you
make wise decisions despite ambiguity; you use data to inform your intuition.
● Candor — you willingly receive and give feedback; you are open about what’s working
and what needs to improve; you admit mistakes openly and share learnings widely.
● Creativity — you welcome new ideas; you are passionate and persistent in pursuit of
more innovative solutions; you value artistic expression.
● Courage — you are vulnerable in search for the truth; you are willing to risk failure, or
challenge the status quo, in the pursuit of excellence.
● Inclusion — you recognize your biases and work to counteract them; you try to ensure
everyone at Netflix can do their best work, whatever their culture, identity or
background.
● Curiosity — you learn rapidly and eagerly; you are more interested in other people’s
ideas than your own; you’re humble about what you don’t yet know.
● Resilience — you quickly adapt to changing circumstances; you make tough decisions
without agonizing or long delay; you embrace a hard challenge.
It’s easy to talk about values and harder to live by them. We all work hard to keep each other
accountable for upholding these standards, especially our leaders, because excellence and
honesty go hand in hand. It’s why we invest in strong professional relationships that build trust
and help people assume good intent. This, in turn, enables us to practice extraordinary
candor — ensuring constructive feedback is part of our everyday work (like brushing your
teeth). It takes courage and vulnerability to ask someone how you could do better, or to seek
alternative opinions about the best way forward, and integrity only to say things about a
colleague that you’re willing to share with them directly. This is especially true when you’re
giving feedback to someone more senior or from a different background, or if you come from
a culture or company where deference is the norm. But extraordinary candor helps us improve
faster as individuals and a company.
Since a high performer in any role is many times more effective than the average employee,
our Dream Team is driven by performance — not seniority, tenure or unconditional loyalty. It’s
also why we focus on maintaining a high performance culture. To recruit and retain stunning
colleagues, we pay personal top of market for the role and location — a judgment about what
that person could make in a similar role at another company, and what we would pay to keep
or replace them. We expect leaders to be strong developers of talent. And to ensure they have
the right player at every position, we ask them to apply what we call the “keeper test”
1 —
asking “if X wanted to leave, would I fight to keep them?” Or “knowing everything I know
today, would I hire X again?” If the answer is no, we believe it’s fairer to everyone to part ways
quickly.
1 The “keeper test” name came from our co-founder, Reed Hastings, who remembers catching a fish as a
child and his dad saying, “That’s a keeper, Reed!”
In the abstract, the keeper test can sound scary. In reality, we encourage everyone to speak to
their managers about what’s going well and what’s not on a regular basis. This helps avoid
surprises. Managers also evaluate team members on their whole record, rather than focusing
on the mistakes or bets that didn’t pay off. On the Dream Team, you need people who
challenge the status quo and try new things. So we stick with employees through short-term
bumps.
No matter how brilliant someone may be, there’s no place in our Dream Team for people who
don’t treat their colleagues with decency and respect. When you have talented people who
work well together — trusting each other’s intentions and respecting their differences — it
makes everyone more successful.
PEOPLE OVER PROCESS
Many of us have worked at companies where decisions were made top down, there was little
transparency and it felt hard to make a difference — or even get basic things done. At Netflix,
we aim to inspire and empower more than just manage because people can have a greater
impact when they’re free to make decisions about their own work.
As part of this, we strive to develop good decision-making muscles at every level of the
company, priding ourselves on how few, not how many, decisions senior leaders make. We
expect managers to practice context not control — giving their teams the context and clarity
needed to make good decisions instead of trying to control everything themselves. We also
help employees learn by sharing a lot of information internally, including through memos
where they can comment and ask questions. It takes an unusually responsible person to
thrive on this level of freedom — someone who’s self-motivated, self-aware and
self-disciplined, who doesn’t wait to be told what to do and picks up the trash like they would
at home. That said, context not control should not be confused with hands-off management.
Managers need to be involved in the work being done around them, and actively coach their
teams. They may also have to step in when someone is about to make a decision that is
unethical or could materially harm Netflix, during a crisis or if a new team member lacks the
full context.
We avoid decision-making by committee, which tends to slow companies down and
undermine accountability. For every significant decision, we identify an informed captain
who’s responsible for making a judgment call on the right way ahead. Then different teams,
each led by their own informed captain, implement the decision. This highly aligned and
loosely coupled approach gives teams the freedom to move quickly and operate
independently, while ensuring responsibility for the outcome.
We’ve learned that the best ideas can come from anywhere, which is why we expect informed
captains to seek out different opinions and listen to people at every level. We call this farming
for dissent. Of course, not all opinions are created equal — and with 10,000-plus employees,
it’s impractical for everyone to weigh in on most decisions (this memo being an exception). So
on an important creative decision, for example, the opinion of someone working in TV, film or
games will carry more weight than an engineer, and vice versa when it comes to our product
or technology. After a decision is made, we expect everyone, including the people who argued
for a different approach, to disagree and commit. This helps ensure the outcome is as
successful as possible. Afterwards, when the impact is clear, the informed captain should
reflect on their choices — what worked and what didn’t — so everyone can learn how to do
better next time.
Launching a game, TV show or film, running a marketing campaign, managing compensation
and closing a quarter all take process. And companies need strict rules against things like
harassment, marginalizing colleagues, leaking company information, or insider trading. But we
work hard to keep rules at Netflix to a minimum and ensure any process is good (simple,
efficient, impactful). Our vacation policy, for example, is two words: “Take vacation.” And our
expenses policy is just five words: “Act in Netflix’s best interests.” This (almost) no rules rule
gives employees the freedom to exercise their judgment. It also prevents the process creep
that typically happens when companies grow and try to dummy proof their organizations —
stifling creativity and making it harder for businesses to adapt.
You might think that this kind of freedom would lead to chaos. In reality, while we’ve had our
fair share of failures — and a few people have taken advantage of our culture in bad ways —
our emphasis on individual autonomy has created an extremely successful business, with
many opportunities for employees to develop and grow. In entertainment and technology, our
biggest threat is a lack of creativity, adaptability and innovation. It’s why trying to minimize
rules and processes (rather than errors) — while giving people the freedom to use their own
judgment and learn from their mistakes — is a far superior recipe for long-term success.
UNCOMFORTABLY EXCITING
Netflix is programming for well over half a billion
2 people globally — something no other
entertainment company has ever done before. Success requires us to be bold and ambitious,
to think differently, experiment and adapt (often quickly). This is true whether we’re designing
a new product feature, working to improve our recommendations, developing a marketing
campaign or creating a TV show or game. Many people will be happier at companies that are
more stable or take fewer risks. Netflix works best if you value experimentation, enjoy the
uncomfortable excitement of a new or challenging project and have the resilience to thrive in
this environment.
ARTISTIC EXPRESSION
Representation matters. Our members come from many different backgrounds and cultures,
and they want to see a wide variety of stories and people on screen. This diversity is
wonderful and it can create real tension since we all have such different views about what’s
acceptable — and what’s harmful — on TV. While every show, film or game is different, we
approach them with the same set of principles: we support the artistic expression of the
creators we choose to work with; we program for a wide variety of audiences, cultures and
tastes; and we provide ratings, content advisories and parental controls in multiple languages
to help members choose what to watch or play. As employees, we support these principles,
even if some stories run counter to our personal values. And we understand that, depending
2 As of Q1 2024 ~260 million households subscribe to Netflix. Assuming ~2 people per household —
which is conservative — that means our audience is over 500M.
on our roles, we may need to work on TV shows, films or games we perceive to be harmful. If
you’d find it hard to support the breadth of our slate, Netflix is probably not the best place for
you.
GREAT AND ALWAYS BETTER
Netflix has come a long way since we mailed our first DVD in 1998. But we're nowhere close
to where we want to be in the future. It’s why we care so much about the Dream Team, putting
people over process and creating an environment where everyone feels a sense of
responsibility to make us better. We believe this approach is the surest path to excellence and
long term success.
It’s also why we constantly seek to improve our culture, not preserve it. Every new employee
helps shape how we work — finding new ways to accomplish more together. This creates a
better experience for our members, employees, creators and partners, which in turn propels
our long term growth and success. It’s how we entertain the world and build a wildly
successful business.
As he has since our first culture deck was written in 2009, Antoine de Saint-Exupéry, the
author of The Little Prince, shows us the way:
If you want to build a ship,
don't drum up the people
to gather wood, divide the
work, and give orders.
Instead, teach them to yearn
for the vast and endless sea.
© 2024 Netflix, Inc. All rights reserved. | Last updated: June 2024 | English Version
"""

# %% [markdown]
# ## Step 3: Chunk the Document

# %%
import re

def chunk_text(text, max_chars=500, overlap=50):
    chunks = []
    n = len(text)
    start = 0

    while start < n:
        hard_end = min(start + max_chars, n)

        if hard_end == n:
            end = n
        else:
            window = text[start:hard_end]
            halfway = len(window) // 2
            end = None

            idx = window.rfind("\n\n")
            if idx != -1 and idx >= halfway:
                end = start + idx + 2

            if end is None:
                idx = window.rfind("\n")
                if idx != -1 and idx >= halfway:
                    end = start + idx + 1

            if end is None:
                matches = list(re.finditer(r"[.!?](?=\s|$)", window))
                if matches and matches[-1].end() >= halfway:
                    end = start + matches[-1].end()

            if end is None:
                idx = window.rfind(" ")
                if idx != -1 and idx >= halfway:
                    end = start + idx + 1

            if end is None:
                end = hard_end

        chunk = text[start:end].strip()
        if chunk:
            chunks.append(chunk)

        if end >= n:
            break

        start = max(end - overlap, start + 1)

    return chunks

# %%
chunks = chunk_text(document, max_chars=500, overlap=50)

# %%
print(chunks)
# Out:
# ['The Best Work of Our Lives\nCULTURE MEMO\nAt Netflix, we aspire to entertain the world, thrilling audiences everywhere. To do that, we’ve\ndeveloped an unusual company culture focused on excellence, and creating an environment\nwhere talented people can thrive — lifting ourselves, each other and our audiences higher and\nhigher. This document is about that culture, which is based on four core principles:\n● The Dream Team: We aim only to have high performers at Netflix — people who are', 'have high performers at Netflix — people who are\ngreat at what they do, and even better at working together.\n● People over Process: You get better outcomes when employees have the information\nand freedom to make decisions for themselves. We hire unusually responsible people\nwho thrive on this openness and freedom.\n● Uncomfortably Exciting: To entertain the world, we need to be bold and ambitious.\nThat means embracing the thrill of what’s next — even when it’s uncomfortable.', 'll of what’s next — even when it’s uncomfortable.\n● Great and Always Better: We often say Netflix sucks today compared to where we can\nbe tomorrow. We need the self-awareness to understand what should be better, and\nthe discipline and resilience to get there.\nWhile we don’t always live up to these principles, most people who join Netflix are pleasantly\nsurprised by how great their colleagues are and the way we empower people at every level.', 'are and the way we empower people at every level.\nAs our business grows and evolves, our culture (and this document) will, too. What won’t\nchange is our focus on excellence, and our determination to ensure that Netflix remains a\nplace where great people can do the best work of their lives. If this sounds exciting, you’ll\nprobably love it here. But Netflix is not for everyone, so please read on.\nTHE DREAM TEAM', 't for everyone, so please read on.\nTHE DREAM TEAM\nWe believe that what makes a fantastic workplace isn’t a great office or free meals and\nmassages — although we have some nice perks. It’s the people. Imagine working alongside\nstunning colleagues who are great at what they do, and even better at working together. It’s\nwhy we model ourselves on a professional sports team, not a family. Families are about\nunconditional love. They can also be dysfunctional, as anyone who’s watched Ozark or', 'e dysfunctional, as anyone who’s watched Ozark or\nWednesday knows. Professional sports teams, on the other hand, focus on performance and\npicking the right person for every position, even when that means swapping out someone\nthey love for a better player.\nWhile every member of our Dream Team has different skills, we look for common strengths\nthat make us better together. These are the values we value:\n● Selflessness — you are humble when searching for the best ideas; you seek what’s', 'hen searching for the best ideas; you seek what’s\nbest for Netflix, not yourself or your team; you take time to help others succeed.\n● Judgment — you look beyond short term fixes in favor of long term solutions; you\nmake wise decisions despite ambiguity; you use data to inform your intuition.\n● Candor — you willingly receive and give feedback; you are open about what’s working\nand what needs to improve; you admit mistakes openly and share learnings widely.', 'admit mistakes openly and share learnings widely.\n● Creativity — you welcome new ideas; you are passionate and persistent in pursuit of\nmore innovative solutions; you value artistic expression.\n● Courage — you are vulnerable in search for the truth; you are willing to risk failure, or\nchallenge the status quo, in the pursuit of excellence.\n● Inclusion — you recognize your biases and work to counteract them; you try to ensure', 'es and work to counteract them; you try to ensure\neveryone at Netflix can do their best work, whatever their culture, identity or\nbackground.\n● Curiosity — you learn rapidly and eagerly; you are more interested in other people’s\nideas  ...

# %%
print(len(chunks))
for i, chunk in enumerate(chunks):
    print(f"Chunk {i + 1}:\n{len(chunk)} characters\n{chunk[:100]}\n{chunk[-100:]}\n{'-' * 40}")
# Out:
# 35
# Chunk 1:
# 484 characters
# The Best Work of Our Lives
# CULTURE MEMO
# At Netflix, we aspire to entertain the world, thrilling audi
# r core principles:
# ● The Dream Team: We aim only to have high performers at Netflix — people who are
# ----------------------------------------
# Chunk 2:
# 478 characters
# have high performers at Netflix — people who are
# great at what they do, and even better at working t
# e bold and ambitious.
# That means embracing the thrill of what’s next — even when it’s uncomfortable.
# ----------------------------------------
# Chunk 3:
# 444 characters
# ll of what’s next — even when it’s uncomfortable.
# ● Great and Always Better: We often say Netflix su
# pleasantly
# surprised by how great their colleagues are and the way we empower people at every level.
# ----------------------------------------
# Chunk 4:
# 412 characters
# are and the way we empower people at every level.
# As our business grows and evolves, our culture (an
# ng, you’ll
# probably love it here. But Netflix is not for everyone, so please read on.
# THE DREAM TEAM
# ----------------------------------------
# Chunk 5:
# 490 characters
# t for everyone, so please read on.
# THE DREAM TEAM
# We believe that what makes a fantastic workplace i
# ilies are about
# unconditional love. They can also be dysfunctional, as anyone who’s watched Ozark or
# ----------------------------------------
# Chunk 6:
# 487 characters
# e dysfunctional, as anyone who’s watched Ozark or
# Wednesday knows. Professional sports teams, on the
#  values we value:
# ● Selflessness — you are humble when searching for the best ideas; you seek what’s
# ----------------------------------------
# Chunk 7:
# 460 characters
# hen searching for the best ideas; you seek what’s
# best for Netflix, not yourself or your team; you t
# bout what’s working
# and what needs to improve; you admit mistakes openly and share learnings widely.
# ----------------------------------------
# Chunk 8:
# 428 characters
# admit mistakes openly and share learnings widely.
# ● Creativity — you welcome new ideas; you are pass
# f excellence.
# ● Inclusion — you recognize your biases and work to counteract them; you try to ensure
# ----------------------------------------
# Chunk 9:
# 442 characters
# es and work to counteract them; you try to ensure
# everyone at Netflix can do their best work, whatev
# rcumstances; you make tough decisions
# without agonizing or long delay; you embrace a hard challenge.
# ----------------------------------------
# Chunk 10:
# 420 characters
# zing or long delay; you embrace a hard challenge.
# It’s easy to talk about values and harder to live
#  build trust
# and help people assume good intent. This, in turn, enables us to practice extraordinary
# ----------------------------------------
# Chunk 11:
# 417 characters
# is, in turn, enables us to practice extraordinary
# candor — ensuring constructive feedback is part of
# out a
# colleague that you’re willing to share with them directly. This is especially true when you’re
# ----------------------------------------
# Chunk 12:
# 455 characters
# hem directly. This is especially true when you’re
# giving feedback to someone more senior or from a d
# oyee,
# our Dream Team is driven by performance — not seniority, tenure or unconditional loyalty. It’s
# ----------------------------------------
# Chunk 13:
# 417 characters
# seniority, tenure or unconditional loyalty. It’s
# also why we focus on maintaining a high performance
# o keep
# or replace them. We expect leaders to be strong developers of talent. And to ensure they have
# ----------------------------------------
# Chunk 14:
# 490 characters
# ong developers of talent. And to ensure they have
# the right player at every position, we ask them to
# Reed Hastings, who remembers catching a fish as a
# child and his dad saying, “That’s a keeper, Reed!”
# ----------------------------------------
# Chunk 15:
# 411 characters
# hild and his dad saying, “That’s a keeper, Reed!”
# In the abstract, the keeper test can sound scary.
# er than focusing
# on the mistakes or bets that didn’t pay off. On the Dream Team, you need people who
# ----------------------------------------
# Chunk 16:
# 470 characters
# t pay off. On the Dream Team, you need people who
# challenge the status quo and try new things. So we
# intentions and respecting their differences — it
# makes everyone more successful.
# PEOPLE OVER PROCESS
# ----------------------------------------
# Chunk 17:
# 474 characters
# kes everyone more successful.
# PEOPLE OVER PROCESS
# Many of us have worked at companies where decision
# r own work.
# As part of this, we strive to develop good decision-making muscles at every level of the
# ----------------------------------------
# Chunk 18:
# 494 characters
# ood decision-making muscles at every level of the
# company, priding ourselves on how few, not how man
#  through memos
# where they can comment and ask questions. It takes an unusually responsible person to
# ----------------------------------------
# Chunk 19:
# 490 characters
# ions. It takes an unusually responsible person to
# thrive on this level of freedom — someone who’s se
# ly coach their
# teams. They may also have to step in when someone is about to make a decision that is
# ----------------------------------------
# Chunk 20:
# 415 characters
# when someone is about to make a decision that is
# unethical or could materially harm Netflix, during
# d captain
# who’s responsible for making a judgment call on the right way ahead. Then different teams,
# ----------------------------------------
# Chunk 21:
# 464 characters
# all on the right way ahead. Then different teams,
# each led by their own informed captain, implement
# ed
# captains to seek out different opinions and listen to people at every level. We call this farming
# ----------------------------------------
# Chunk 22:
# 422 characters
# en to people at every level. We call this farming
# for dissent. Of course, not all opinions are creat
# , film or
# games will carry more weight than an engineer, and vice versa when it comes to our product
# ----------------------------------------
# Chunk 23:
# 425 characters
# neer, and vice versa when it comes to our product
# or technology. After a decision is made, we expect
# t on their choices — what worked and what didn’t — so everyone can learn how to do
# better next time.
# ----------------------------------------
# Chunk 24:
# 410 characters
# so everyone can learn how to do
# better next time.
# Launching a game, TV show or film, running a marke
# ding. But we
# work hard to keep rules at Netflix to a minimum and ensure any process is good (simple,
# ----------------------------------------
# Chunk 25:
# 489 characters
# a minimum and ensure any process is good (simple,
# efficient, impactful). Our vacation policy, for ex
#  dummy proof their organizations —
# stifling creativity and making it harder for businesses to adapt.
# ----------------------------------------
# Chunk 26:
# 414 characters
# ity and making it harder for businesses to adapt.
# You might think that this kind of freedom would le
# ess, with
# many opportunities for employees to develop and grow. In entertainment and technology, our
# ----------------------------------------
# Chunk 27:
# 441 characters
# op and grow. In entertainment and technology, our
# biggest threat is a lack of creativity, adaptabili
#  EXCITING
# Netflix is programming for well over half a billion
# 2 people globally — something no other
# ----------------------------------------
# Chunk 28:
# 411 characters
# a billion
# 2 people globally — something no other
# entertainment company has ever done before. Success
#  marketing
# campaign or creating a TV show or game. Many people will be happier at companies that are
# ----------------------------------------
# Chunk 29:
# 447 characters
# Many people will be happier at companies that are
# more stable or take fewer risks. Netflix works bes
# and cultures,
# and they want to see a wide variety of stories and people on screen. This diversity is
# ----------------------------------------
# Chunk 30:
# 410 characters
# f stories and people on screen. This diversity is
# wonderful and it can create real tension since we
# ion of the
# creators we choose to work with; we program for a wide variety of audiences, cultures and
# ----------------------------------------
# Chunk 31:
# 483 characters
# ram for a wide variety of audiences, cultures and
# tastes; and we provide ratings, content advisories
# ix. Assuming ~2 people per household —
# which is conservative — that means our audience is over 500M.
# ----------------------------------------
# Chunk 32:
# 453 characters
# servative — that means our audience is over 500M.
# on our roles, we may need to work on TV shows, fil
# e close
# to where we want to be in the future. It’s why we care so much about the Dream Team, putting
# ----------------------------------------
# Chunk 33:
# 424 characters
# why we care so much about the Dream Team, putting
# people over process and creating an environment wh
#  new employee
# helps shape how we work — finding new ways to accomplish more together. This creates a
# ----------------------------------------
# Chunk 34:
# 486 characters
# ways to accomplish more together. This creates a
# better experience for our members, employees, creat
# you want to build a ship,
# don't drum up the people
# to gather wood, divide the
# work, and give orders.
# ----------------------------------------
# Chunk 35:
# 194 characters
# to gather wood, divide the
# work, and give orders.
# Instead, teach them to yearn
# for the vast and endl
# d endless sea.
# © 2024 Netflix, Inc. All rights reserved. | Last updated: June 2024 | English Version
# ----------------------------------------

# %% [markdown]
# ## Step 4: Visualize the Embeddings

# %%
# Generate Embeddings for all chunks
response = client.embeddings.create(
    model = "text-embedding-3-small",
    input = chunks
)

embeddings = [item.embedding for item in response.data]

# %%
from pprint import pprint
pprint(response.data)
# Out:
# [Embedding(embedding=[0.03436279296875, 0.020843505859375, -0.042816162109375, 0.03607177734375, 0.03326416015625, -0.055999755859375, -0.032867431640625, 0.05950927734375, -0.0323486328125, 0.00734710693359375, 0.036468505859375, -0.0157623291015625, -0.03802490234375, -0.046295166015625, 0.022308349609375, 0.0285186767578125, -0.0197601318359375, -0.041351318359375, 0.00359344482421875, -0.051055908203125, 0.0192413330078125, 0.035400390625, -0.0061798095703125, 0.0201416015625, 0.01148223876953125, 0.01202392578125, -0.07470703125, 0.07183837890625, -0.0284881591796875, -0.0206756591796875, -0.0281524658203125, -0.0174102783203125, 0.025848388671875, -0.01171112060546875, 0.0372314453125, 0.023895263671875, 0.0216064453125, 0.0015172958374023438, 0.039337158203125, -0.0038604736328125, 0.00015604496002197266, -0.017181396484375, 0.06390380859375, 0.03521728515625, 0.0163421630859375, -0.025115966796875, 0.0051116943359375, 0.0227813720703125, 0.0180816650390625, 0.059356689453125, -0.08184814453125, 0.0457763671875, -0.01508331298828125, 0.01186370849609375, -0.040557861328125, -0.01349639892578125, 0.00746917724609375, -0.002597808837890625, -0.04864501953125, -0.00023448467254638672, 0.02978515625, 0.01041412353515625, -0.006404876708984375, -0.004711151123046875, 0.0203857421875, -0.0071868896484375, -0.08203125, -0.018829345703125, 0.0015125274658203125, 0.0124359130859375, 0.0545654296875, 0.024871826171875, -0.0283660888671875, 0.01611328125, 0.01160430908203125, -0.07269287109375, -0.009765625, -0.029266357421875, 0.00395965576171875, -0.08978271484375, 0.007076263427734375, 0.03485107421875, 0.02130126953125, 0.05029296875, -0.0191192626953125, -0.038055419921875, -0.04620361328125, 0.0093231201171875, -0.060943603515625, 0.006656646728515625, 0.006244659423828125, 0.036163330078125, -0.032958984375, 0.02362060546875, 0.0293121337890625, 0.01226806640625, 0.03076171875, 0.0214080810546875, 0.037109375, -0.001605987548828125, 0.0125885009765625, 0.0026988983154296875, -0.0178680419921875, 0.0041656494140625, 0.041259765625, 0.049102783203125, 0.01025390625, -0.048553466796875, -0.037445068359375, -0.031341552734375, -0.11962890625, -0.005191802978515625, -0.009063720703125, 0.00972747802734375, 0.0103912353515625, 0.0038928985595703125, 0.03076171875, -0.02032470703125, 0.0247802734375, 0.0172119140625, -0.0186767578125, 0.0218353271484375, -0.0054931640625, -0.0343017578125, -0.01113128662109375, -0.0217132568359375, 0.020050048828125, 0.029388427734375, -0.03802490234375, -0.08074951171875, 0.0391845703125, -0.0389404296875, 0.00817108154296875, -0.03424072265625, 0.001140594482421875, 0.01556396484375, -0.0772705078125, -0.01047515869140625, -0.0037136077880859375, 0.06304931640625, -0.0203399658203125, -0.010467529296875, 0.003849029541015625, -0.016082763671875, 0.0105743408203125, -0.0271453857421875, -0.0227508544921875, -0.01136016845703125, -0.00957489013671875, 0.00020706653594970703, -0.01519012451171875, 0.0112457275390625, -0.048797607421875, 0.037750244140625, 0.00923919677734375, -0.039520263671875, -0.00109100341796875, 0.048858642578125, -0.02337646484375, -0.043609619140625, 0.0321044921875, -0.024444580078125, -0.05810546875, 0.0164642333984375, -0.0006985664367675781, -0.00402069091796875, -0.0455322265625, -0.0174407958984375, -0.06951904296875, -0.014556884765625, -0.00954437255859375, 0.00783538818359375, -0.046722412109375, 0.023284912109375, 0.0295257568359375, -0.034332275390625, -0.026702880859375, -0.0095367431640625, -0.044769287109375, -0.035308837890625, -0.027923583984375, -0.00739288330078125, -0.01056671142578125, -0.011322021484375, -0.005764007568359375, 0.044708251953125, -0.01151275634765625, 0.0101470947265625, -0.0010499954223632812, -0.0193939208984375, -0.046295166015625, -0.004718780517578125, 0.0006451606750488281, -0.0231170654296875, -0.01331329345703125, 0.0021953582763671875, 0.010711669921875, 0.01433563232421875, 0.0157012939453125, 0.04931640625, -0.013275146484375,  ...
#  Embedding(embedding=[0.0249176025390625, 0.015960693359375, -0.00736236572265625, 0.051513671875, 0.06671142578125, -0.0308837890625, 0.0010614395141601562, 0.046783447265625, 0.000751495361328125, -0.0036983489990234375, 0.05780029296875, 0.0005064010620117188, -0.0239715576171875, -0.0211944580078125, 0.03338623046875, 0.017578125, -0.0225067138671875, -0.034576416015625, 0.00516510009765625, -0.0423583984375, 0.012176513671875, 0.060546875, -0.00556182861328125, 0.0232391357421875, -0.031402587890625, 0.0343017578125, -0.07867431640625, 0.0721435546875, 0.0003762245178222656, 0.0023403167724609375, 0.0128936767578125, -0.0164642333984375, 0.023468017578125, -0.00878143310546875, 0.055389404296875, 0.017547607421875, -0.007213592529296875, -0.0016736984252929688, 0.03466796875, -0.0124664306640625, -0.03265380859375, 0.0157318115234375, 0.008758544921875, 0.020660400390625, 0.035919189453125, -0.0272979736328125, -0.0092926025390625, -0.04656982421875, 0.0127410888671875, 0.03375244140625, -0.048736572265625, 0.040374755859375, -0.021270751953125, 0.016510009765625, -0.04052734375, 0.016326904296875, 0.00525665283203125, -0.028289794921875, -0.03155517578125, 0.00444793701171875, 0.03936767578125, -0.02349853515625, 0.03314208984375, 0.017120361328125, 0.003513336181640625, -0.031951904296875, -0.0758056640625, -0.005046844482421875, -0.0029773712158203125, 0.026092529296875, 0.053497314453125, 0.020233154296875, -0.044647216796875, 0.034820556640625, 0.036712646484375, -0.039794921875, 0.024261474609375, -0.0245361328125, 0.00974273681640625, -0.06060791015625, 0.005687713623046875, 0.004100799560546875, 0.01377105712890625, -0.007526397705078125, -0.017242431640625, 0.0270843505859375, -0.024169921875, -0.05572509765625, -0.069580078125, 0.00351715087890625, 0.00843048095703125, 0.04022216796875, -0.0038776397705078125, 0.0305633544921875, -0.004055023193359375, -0.0009059906005859375, 0.033203125, 0.04791259765625, 0.039154052734375, -0.00024700164794921875, -0.0120086669921875, -0.0055694580078125, -0.0120391845703125, -0.0211181640625, 0.035980224609375, 0.00450897216796875, -0.0180816650390625, -0.0043792724609375, -0.00707244873046875, -0.047454833984375, -0.10186767578125, -0.005565643310546875, -0.0020236968994140625, 0.0404052734375, -0.027191162109375, -0.023284912109375, 0.027191162109375, -0.01432037353515625, 0.0360107421875, 0.038299560546875, 0.006534576416015625, 0.00467681884765625, -0.017852783203125, -0.0189208984375, -0.0377197265625, -0.003971099853515625, 0.0176544189453125, 0.030364990234375, -0.01459503173828125, -0.07904052734375, 0.028717041015625, -0.037384033203125, 0.001651763916015625, -0.038909912109375, -0.01355743408203125, 0.05523681640625, -0.054351806640625, -0.027191162109375, 0.0163116455078125, 0.07281494140625, -0.0247955322265625, -0.018798828125, -0.0028514862060546875, -0.0272216796875, 0.0038604736328125, -0.016845703125, -0.0057220458984375, 0.005397796630859375, -0.0479736328125, 0.006359100341796875, -0.031524658203125, 0.0212249755859375, -0.06536865234375, 0.018890380859375, 0.011199951171875, -0.041656494140625, -0.0131683349609375, 0.049072265625, 0.01324462890625, -0.04345703125, 0.0340576171875, -0.0151214599609375, -0.0244140625, 0.0296173095703125, 0.04925537109375, 0.005565643310546875, -0.0120697021484375, -0.040557861328125, -0.0210418701171875, 0.0212249755859375, 0.00811767578125, -0.0201568603515625, -0.04827880859375, 0.046539306640625, 0.07720947265625, -0.0128326416015625, -0.011260986328125, 0.012237548828125, -0.0237884521484375, -0.04986572265625, -0.033782958984375, -0.007198333740234375, 0.003963470458984375, -0.01113128662109375, 0.0086212158203125, 0.01174163818359375, -0.031158447265625, 0.02105712890625, -0.0277557373046875, -0.0096282958984375, -0.06072998046875, 0.03607177734375, 0.00225830078125, 0.0034332275390625, 0.0001901388168334961, -0.0290374755859375, 0.042724609375, 0.001842498779296875, 0.005184173583984375, 0.043853759765625, 0.003416061 ...
#  Embedding(embedding=[0.0017957687377929688, 0.0096588134765625, -0.0220489501953125, 0.07708740234375, 0.050750732421875, -0.02374267578125, 0.0221099853515625, 0.04888916015625, 0.0034160614013671875, 0.0164642333984375, 0.03302001953125, -0.01224517822265625, -0.056182861328125, -0.0438232421875, 0.020538330078125, 0.02252197265625, 0.03350830078125, -0.0004508495330810547, 0.0245208740234375, -0.007633209228515625, -0.01297760009765625, 0.010162353515625, -0.01396942138671875, 0.03717041015625, -0.052001953125, 0.00543212890625, -0.0452880859375, 0.0814208984375, 0.01483154296875, 0.0172576904296875, 0.0153656005859375, -0.0313720703125, -0.014678955078125, -0.00551605224609375, 0.04266357421875, 0.060760498046875, 0.0209197998046875, -0.0061798095703125, 0.04315185546875, -0.011962890625, -0.0255889892578125, 0.030181884765625, 0.0101776123046875, 0.01479339599609375, 0.0304718017578125, -0.0382080078125, -0.03863525390625, -0.01270294189453125, -0.0163116455078125, 0.05126953125, -0.05804443359375, 0.00907135009765625, -0.035919189453125, 0.0104217529296875, -0.04461669921875, 0.0031909942626953125, 0.00653839111328125, -0.00817108154296875, -0.0150604248046875, -0.00708770751953125, -0.0170135498046875, 0.0131378173828125, 0.022796630859375, 0.0150909423828125, 0.019683837890625, -0.033599853515625, -0.043670654296875, -0.0204315185546875, 0.005199432373046875, -0.004550933837890625, 0.01166534423828125, 0.020538330078125, -0.0511474609375, 0.0086212158203125, 0.006610870361328125, -0.020233154296875, 0.049102783203125, -0.0282440185546875, 0.051788330078125, -0.054595947265625, -0.01171112060546875, 0.025482177734375, -0.031707763671875, 0.013946533203125, 0.0112762451171875, -0.0207061767578125, -0.032989501953125, -0.03076171875, -0.032501220703125, 0.00328826904296875, 0.021453857421875, -0.025970458984375, -0.043060302734375, 0.033172607421875, 0.007965087890625, -0.00745391845703125, 0.05352783203125, 0.0192413330078125, 0.04608154296875, -0.00537872314453125, 0.0175323486328125, -0.0222930908203125, -0.011962890625, -0.009674072265625, 0.066650390625, 0.0201416015625, 0.013671875, -0.019012451171875, -0.02459716796875, -0.0219879150390625, -0.10504150390625, -0.02093505859375, -0.0157928466796875, 0.046630859375, -0.03900146484375, 0.00218963623046875, -0.00322723388671875, 0.0011491775512695312, 0.041839599609375, 0.03948974609375, 0.0240936279296875, -0.0234375, -0.030303955078125, -0.0177001953125, -0.009613037109375, -0.05096435546875, 0.004825592041015625, 0.01739501953125, -0.03985595703125, -0.03741455078125, 0.0213623046875, -0.0186614990234375, -0.01343536376953125, -0.0122528076171875, -0.032470703125, 0.0070648193359375, -0.06646728515625, -0.0428466796875, 0.027374267578125, 0.0230255126953125, -0.011199951171875, -0.045928955078125, 0.00269317626953125, -0.051422119140625, 0.027374267578125, -0.0182342529296875, 0.0210418701171875, 0.024627685546875, -0.026947021484375, 0.002735137939453125, 0.00334930419921875, 0.04034423828125, -0.08319091796875, 0.039825439453125, 0.0024700164794921875, -0.0105743408203125, -0.02862548828125, 0.058380126953125, -0.01004791259765625, -0.0345458984375, -0.0177001953125, -0.006900787353515625, -0.06317138671875, 0.01058197021484375, 0.03936767578125, -0.00984954833984375, -0.0243377685546875, -0.031829833984375, -0.038970947265625, -0.03326416015625, 0.0269775390625, -0.019622802734375, -0.001659393310546875, -0.00627899169921875, 0.062225341796875, -0.01244354248046875, 0.00806427001953125, -0.032958984375, -0.0168304443359375, -0.03692626953125, -0.0021343231201171875, -0.0004315376281738281, 0.01629638671875, -0.04351806640625, 0.0158233642578125, 0.039093017578125, -0.0506591796875, 0.032501220703125, -0.0246734619140625, -0.02935791015625, -0.06707763671875, 0.01611328125, 0.0107421875, 0.017669677734375, -0.00989532470703125, -0.018798828125, 0.020843505859375, 0.00975799560546875, 0.0238800048828125, 0.03350830078125, 0.001094818115234375, 0.000415325164794921 ...
#  Embedding(embedding=[0.03057861328125, 0.018890380859375, -0.04913330078125, 0.025665283203125, 0.0401611328125, -0.038299560546875, -0.00612640380859375, 0.049774169921875, -0.039794921875, -0.0038967132568359375, 0.01153564453125, -0.005443572998046875, -0.031219482421875, -0.003719329833984375, 0.015869140625, 0.0426025390625, 0.01160430908203125, -0.0256500244140625, 0.0066986083984375, -0.0280914306640625, 0.0270538330078125, 0.04498291015625, -0.00872802734375, 0.03363037109375, -0.01184844970703125, 0.038726806640625, -0.035888671875, 0.0838623046875, -0.018829345703125, -0.01457977294921875, -0.001068115234375, -0.0157928466796875, 0.00835418701171875, 0.0208892822265625, 0.050445556640625, 0.0092620849609375, 0.027984619140625, 0.003597259521484375, 0.0419921875, -0.01557159423828125, -0.017730712890625, -0.01380157470703125, 0.07611083984375, 0.04345703125, 0.0031261444091796875, -0.0005283355712890625, -0.0215911865234375, 0.01314544677734375, 0.02099609375, 0.033477783203125, -0.06451416015625, 0.0193328857421875, -0.008392333984375, 0.01236724853515625, -0.033538818359375, -0.006595611572265625, 0.00591278076171875, -0.0095367431640625, -0.0484619140625, 0.01412200927734375, 0.02008056640625, 0.01328277587890625, -0.01010894775390625, 0.020843505859375, 0.0008206367492675781, -0.00963592529296875, -0.09130859375, -0.002044677734375, 0.0121917724609375, 0.00026679039001464844, 0.0611572265625, 0.016387939453125, -0.054779052734375, 0.03912353515625, 0.006359100341796875, -0.057281494140625, -0.038238525390625, -0.0170440673828125, -0.004364013671875, -0.046051025390625, -0.00891876220703125, 0.032928466796875, -0.004688262939453125, 0.037109375, -0.011505126953125, -0.033233642578125, -0.04791259765625, -0.0017900466918945312, -0.057037353515625, 0.022125244140625, -0.0176239013671875, 0.0142669677734375, -0.031219482421875, 0.0322265625, 0.04412841796875, 0.0210113525390625, 0.034515380859375, 0.002410888671875, 0.035186767578125, -0.0133514404296875, 0.0302581787109375, -0.02642822265625, -0.0172271728515625, -0.0181427001953125, 0.06353759765625, 0.0237884521484375, -0.005054473876953125, -0.048797607421875, -0.02471923828125, -0.04400634765625, -0.1385498046875, -0.002655029296875, 0.035980224609375, 0.0300140380859375, -0.0256500244140625, 0.0234375, 0.031707763671875, -0.0231781005859375, 0.0222625732421875, 0.027252197265625, 0.00276947021484375, -0.0079498291015625, -0.0074920654296875, -0.0200042724609375, -0.020965576171875, -0.032562255859375, -0.021881103515625, 0.0438232421875, -0.067138671875, -0.05352783203125, 0.0222320556640625, -0.0426025390625, 0.016998291015625, -0.0302886962890625, -0.0379638671875, 0.00860595703125, -0.10906982421875, 0.0036182403564453125, 0.00043511390686035156, 0.04345703125, 0.0243072509765625, -0.027191162109375, -0.0300445556640625, -0.028594970703125, -0.0185546875, -0.061065673828125, -0.012298583984375, -0.007106781005859375, -0.0286407470703125, -0.002227783203125, 0.005809783935546875, 0.0015707015991210938, -0.0692138671875, 0.006290435791015625, -0.01702880859375, -0.018890380859375, -0.0092315673828125, 0.0478515625, -0.032318115234375, -0.0010671615600585938, 0.0025463104248046875, -0.017364501953125, -0.026458740234375, -0.00811004638671875, 0.0225830078125, -0.0021724700927734375, -0.0164794921875, -0.032958984375, -0.0643310546875, -0.0093841552734375, -0.040985107421875, -0.0194244384765625, -0.06451416015625, 0.00984954833984375, 0.053070068359375, -0.023590087890625, -0.0263519287109375, -0.0095672607421875, -0.025299072265625, -0.054901123046875, -0.0008111000061035156, -0.01480865478515625, -0.0051116943359375, -0.061492919921875, -0.0196533203125, 0.0191802978515625, -0.0190582275390625, 0.042572021484375, -0.019134521484375, -0.0224609375, -0.062347412109375, 0.032379150390625, -0.0139923095703125, -0.0222625732421875, -0.015594482421875, -0.0164947509765625, 0.04248046875, -0.00608062744140625, -0.005527496337890625, 0.060028076171875, 0.006843566894 ...
#  Embedding(embedding=[0.0189666748046875, 0.035552978515625, -0.05413818359375, 0.018829345703125, 0.034515380859375, -0.05133056640625, 0.0025806427001953125, 0.0538330078125, -0.0235443115234375, -0.0160369873046875, 0.00037026405334472656, -0.0189361572265625, -0.01410675048828125, -0.0213470458984375, 0.02484130859375, 0.012542724609375, 0.026763916015625, -0.0648193359375, -0.016693115234375, 0.0143585205078125, 0.01363372802734375, 0.050445556640625, -0.0224151611328125, -0.00701141357421875, 0.006107330322265625, 0.0511474609375, -0.01334381103515625, 0.0192718505859375, 0.0028820037841796875, -0.0162506103515625, -0.018280029296875, -0.0290374755859375, -0.00547027587890625, 0.01018524169921875, 0.0540771484375, 0.047698974609375, 0.0196380615234375, 0.0019121170043945312, 0.043212890625, -0.00045228004455566406, -0.002315521240234375, 0.04010009765625, 0.0609130859375, 0.01629638671875, -0.026214599609375, -0.013824462890625, -0.0216064453125, 0.01174163818359375, 0.01551055908203125, -0.00030112266540527344, -0.05401611328125, 0.01136016845703125, -0.00627899169921875, 0.00391387939453125, -0.038116455078125, -0.00472259521484375, -0.025421142578125, 0.0123291015625, 0.008819580078125, -0.0131378173828125, 0.018280029296875, 0.00641632080078125, -0.0004363059997558594, 0.07379150390625, -0.015899658203125, -0.0300445556640625, -0.04510498046875, 0.01161956787109375, -0.0239715576171875, 0.023284912109375, 0.059173583984375, 0.036895751953125, -0.053680419921875, 0.040191650390625, 0.0164642333984375, -0.0914306640625, -0.031707763671875, -0.006130218505859375, -0.0265655517578125, -0.037933349609375, 0.020721435546875, 0.0308685302734375, 0.0194091796875, 0.0280303955078125, -0.02435302734375, -0.06524658203125, -0.04656982421875, -0.01480865478515625, -0.00641632080078125, 0.00576019287109375, 0.002899169921875, 0.01366424560546875, -0.005474090576171875, -0.00963592529296875, 0.059539794921875, -0.0181121826171875, 0.006084442138671875, 0.0158233642578125, -0.004085540771484375, -0.0249786376953125, 0.030242919921875, -0.0745849609375, -0.03289794921875, -0.0087432861328125, 0.059051513671875, -0.001506805419921875, -0.01354217529296875, -0.0360107421875, -0.0206146240234375, 0.0269012451171875, -0.1427001953125, 0.027801513671875, 0.0028667449951171875, 0.0269012451171875, -0.03961181640625, -0.004978179931640625, -0.010833740234375, -0.034271240234375, 0.0033416748046875, -0.018798828125, 0.0177154541015625, 0.0007085800170898438, -0.01348114013671875, 0.02099609375, -0.0340576171875, -0.005985260009765625, -0.046905517578125, -0.019561767578125, -0.03778076171875, -0.068115234375, 0.005832672119140625, -0.0389404296875, -0.019378662109375, -0.005016326904296875, -0.0228271484375, -0.00909423828125, -0.060028076171875, -0.016326904296875, -0.004146575927734375, 0.0237274169921875, 0.047760009765625, -0.051544189453125, -0.023193359375, -0.046783447265625, 0.0244903564453125, -0.0216827392578125, -0.00876617431640625, 0.03460693359375, -0.055511474609375, -0.013092041015625, -0.014190673828125, -0.01255035400390625, -0.0135040283203125, -0.01548004150390625, 0.01331329345703125, -0.0167388916015625, 0.006591796875, -0.006908416748046875, -0.006099700927734375, -0.0169219970703125, 0.0240020751953125, 0.008636474609375, -0.0287628173828125, 0.0243682861328125, 0.036895751953125, 0.027069091796875, -0.0511474609375, -0.049407958984375, -0.0545654296875, -0.03363037109375, -0.0120086669921875, -0.0027599334716796875, -0.04144287109375, 0.0687255859375, 0.045013427734375, -0.022674560546875, 0.0008440017700195312, -0.00860595703125, -0.046844482421875, -0.06292724609375, 0.00821685791015625, -0.01088714599609375, -0.0237274169921875, -0.036407470703125, 0.0278167724609375, 0.012237548828125, -0.01849365234375, -0.0168914794921875, -0.0183563232421875, 0.0169525146484375, -0.0372314453125, 0.026031494140625, 0.003101348876953125, -0.026824951171875, 0.0211639404296875, -0.03472900390625, 0.03631591796875, 0.04443359375 ...
#  Embedding(embedding=[0.0205230712890625, 0.0243988037109375, -0.006927490234375, 0.0229034423828125, 0.045562744140625, -0.03289794921875, 0.0188446044921875, 0.0296630859375, -0.02655029296875, 0.019989013671875, 0.0206298828125, -0.03875732421875, -0.0357666015625, 0.0189666748046875, 0.0633544921875, 0.002101898193359375, 3.6835670471191406e-05, -0.06768798828125, -0.035552978515625, -0.004268646240234375, 0.01068878173828125, 0.0284271240234375, -0.001491546630859375, -0.0080108642578125, 0.01346588134765625, 0.058746337890625, -0.0034732818603515625, 0.053955078125, -0.01531219482421875, 0.00795745849609375, 0.011566162109375, -0.02423095703125, 0.01064300537109375, -0.0260467529296875, 0.01837158203125, 0.0296630859375, 0.00841522216796875, 0.024139404296875, 0.033538818359375, 0.00463104248046875, 0.0157928466796875, 0.02587890625, 0.0183868408203125, 0.0042572021484375, 0.0091552734375, -0.012054443359375, -0.027191162109375, -0.03369140625, 0.011444091796875, -0.003032684326171875, -0.035430908203125, 0.04888916015625, 0.017608642578125, -0.00553131103515625, 0.0297088623046875, 0.01262664794921875, -0.017669677734375, 0.0182342529296875, 0.004993438720703125, 0.034698486328125, 0.006465911865234375, 0.006092071533203125, 0.00868988037109375, 0.06561279296875, -0.01120758056640625, -0.041412353515625, -0.0662841796875, -0.0262451171875, -0.02410888671875, 0.038330078125, 0.0251007080078125, -0.01531219482421875, -0.034698486328125, 0.040374755859375, 0.044830322265625, -0.034698486328125, 0.01378631591796875, -0.0017185211181640625, 0.00688934326171875, -0.016693115234375, 0.029022216796875, 0.027069091796875, 0.00701141357421875, 0.03497314453125, -0.0207366943359375, -0.047454833984375, -0.03387451171875, -0.0675048828125, 0.0138092041015625, -0.01132965087890625, -0.034942626953125, -0.01207733154296875, 0.012939453125, 0.0052337646484375, 0.0177001953125, 0.001659393310546875, 0.03546142578125, 0.004161834716796875, 0.0213470458984375, -0.00724029541015625, -0.0103912353515625, -0.05224609375, -0.04888916015625, 0.01580810546875, 0.058929443359375, -0.0116729736328125, -0.0234375, -0.00984954833984375, -0.044036865234375, 0.0144805908203125, -0.1168212890625, -0.0120697021484375, -0.034210205078125, 0.01372528076171875, -0.042083740234375, -0.0243377685546875, 0.005100250244140625, -0.023651123046875, 0.01045989990234375, -0.012176513671875, 0.0078125, 0.01593017578125, -0.01491546630859375, -0.0007753372192382812, -0.0634765625, 0.0018301010131835938, -0.0074005126953125, 0.006969451904296875, -0.033111572265625, -0.09112548828125, -0.018646240234375, -0.0166168212890625, -0.0180206298828125, 0.004482269287109375, -0.0182342529296875, 0.01910400390625, -0.04693603515625, -0.0205841064453125, 0.04058837890625, 0.05841064453125, 0.0187225341796875, -0.041168212890625, 0.00714111328125, -0.006580352783203125, 0.0219573974609375, 0.02490234375, 0.01552581787109375, 0.0439453125, -0.0804443359375, 0.00962066650390625, 0.01032257080078125, -0.042938232421875, -0.00980377197265625, -0.029541015625, -0.0007581710815429688, -0.032745361328125, -0.005817413330078125, -0.004573822021484375, 0.0031375885009765625, -0.038299560546875, 0.0306243896484375, 0.0165863037109375, -0.05462646484375, -0.004474639892578125, 0.0616455078125, -0.01076507568359375, -0.0318603515625, -0.023712158203125, -0.026153564453125, -0.0413818359375, -0.0102996826171875, -0.047393798828125, -0.026702880859375, 0.03765869140625, 0.037139892578125, -0.0201568603515625, -0.01666259765625, 0.0013666152954101562, -0.02642822265625, -0.057098388671875, -0.018707275390625, -0.03167724609375, 0.004871368408203125, -0.0218505859375, 0.0301971435546875, 0.01506805419921875, -0.05029296875, -0.022125244140625, -0.0152587890625, -0.0127410888671875, -0.00534820556640625, 0.026885986328125, 0.0079803466796875, -0.036773681640625, 0.03094482421875, -0.007366180419921875, 0.03399658203125, 0.04345703125, 0.01678466796875, 0.06683349609375, -0.01519775390625, 0.0 ...
#  Embedding(embedding=[0.007320404052734375, 0.0144500732421875, 0.01107025146484375, 0.04449462890625, 0.054931640625, -0.05169677734375, -0.0226593017578125, 0.044891357421875, -0.00743865966796875, 0.067138671875, 0.07470703125, -0.0164642333984375, -0.0135955810546875, -0.045013427734375, 0.057769775390625, 0.0301971435546875, -0.01509857177734375, -0.0275115966796875, 0.006122589111328125, 0.0156097412109375, 0.01268768310546875, 0.044403076171875, 0.007465362548828125, 0.0782470703125, 0.016448974609375, 0.0281829833984375, -0.00637054443359375, 0.08978271484375, 0.0270233154296875, -0.001247406005859375, 0.0255126953125, -0.01238250732421875, -0.042083740234375, -0.0157318115234375, 0.0310516357421875, 0.035552978515625, -0.0180206298828125, -0.049041748046875, 0.04412841796875, -0.01541900634765625, -0.057281494140625, 0.002910614013671875, 0.02587890625, 0.0025882720947265625, 0.025848388671875, -0.08447265625, -0.0161285400390625, -0.03271484375, 0.029876708984375, 0.0152587890625, -0.05316162109375, 0.033416748046875, -0.00777435302734375, 0.032470703125, -0.016693115234375, -0.00460052490234375, -0.017578125, 0.022552490234375, -0.0019741058349609375, 0.045318603515625, -0.0177459716796875, 0.00998687744140625, 0.004802703857421875, -0.003265380859375, 0.00673675537109375, -0.040771484375, -0.053741455078125, -0.023101806640625, -0.0164642333984375, 0.004764556884765625, 0.030609130859375, 0.0279693603515625, -0.02008056640625, -0.01255035400390625, 0.005218505859375, -0.017852783203125, 0.0599365234375, 0.0163116455078125, -0.00876617431640625, -0.060791015625, 0.005733489990234375, 0.024627685546875, -0.0020847320556640625, -0.006092071533203125, 0.0308074951171875, 0.00598907470703125, -0.042083740234375, -0.018890380859375, -0.032470703125, 0.0024852752685546875, 0.004302978515625, 0.0158843994140625, -0.01424407958984375, 0.0272674560546875, -0.0222930908203125, -0.00875091552734375, 0.0521240234375, -0.0007271766662597656, 0.03289794921875, 0.006938934326171875, 0.03424072265625, 0.00937652587890625, -0.0166168212890625, 0.0201568603515625, 0.0223846435546875, 0.01245880126953125, -0.032928466796875, 0.00806427001953125, -0.01412200927734375, -0.01277923583984375, -0.109375, -0.0042572021484375, -0.0202178955078125, 0.033447265625, -0.02349853515625, -0.0118255615234375, -0.041107177734375, -0.0281829833984375, 0.03564453125, 0.042877197265625, 0.0229339599609375, 0.01255035400390625, -0.01067352294921875, 0.001068115234375, -0.0056915283203125, -0.01123809814453125, 0.0212860107421875, 0.00994873046875, -0.00992584228515625, -0.058624267578125, 0.006927490234375, -0.00185394287109375, 0.0257415771484375, -0.053558349609375, -0.01137542724609375, -0.0080108642578125, -0.0599365234375, -0.0286407470703125, -0.033203125, 0.0296173095703125, -0.0224609375, 0.01441192626953125, 0.016448974609375, -0.00896453857421875, -0.021392822265625, -0.047271728515625, -0.0004067420959472656, 0.0206756591796875, -0.057861328125, 0.044281005859375, -0.0222320556640625, 0.01094818115234375, -0.046539306640625, 0.01084136962890625, -0.00580596923828125, -0.00860595703125, -0.019683837890625, 0.015289306640625, -0.028411865234375, -0.04315185546875, 0.020660400390625, 0.024383544921875, -0.020233154296875, 0.016204833984375, 0.004581451416015625, -0.01277923583984375, -0.0020961761474609375, -0.0224609375, -0.0262603759765625, 0.0007419586181640625, -0.00173187255859375, -0.0689697265625, 0.00763702392578125, 0.029296875, 0.0799560546875, 0.0182647705078125, -0.00811767578125, -0.004119873046875, -0.0207672119140625, -0.0249176025390625, -0.051025390625, -0.0015096664428710938, -0.021820068359375, -0.0200042724609375, 0.027313232421875, 0.0396728515625, -0.050048828125, 0.0274505615234375, 0.0028667449951171875, -0.05633544921875, -0.06640625, 0.02813720703125, 0.04022216796875, 0.023773193359375, 0.02825927734375, -0.0174102783203125, 0.03765869140625, 0.01328277587890625, 0.0166778564453125, 0.036651611328125, -0.02734375, -0.0 ...
#  Embedding(embedding=[0.0469970703125, -0.019195556640625, 0.046722412109375, 0.07891845703125, 0.033050537109375, -0.03826904296875, -0.02349853515625, 0.06390380859375, -0.01641845703125, 0.060028076171875, 0.06878662109375, -0.00675201416015625, 0.00882720947265625, -0.01306915283203125, 0.02484130859375, 0.0518798828125, -0.023345947265625, -0.01087188720703125, 0.0369873046875, -0.00266265869140625, 0.0258941650390625, 0.007495880126953125, -0.00836944580078125, 0.10174560546875, -0.00043845176696777344, 0.0284423828125, -0.012237548828125, 0.020477294921875, 0.0304412841796875, 0.0284423828125, 0.0305328369140625, -0.006984710693359375, -0.036529541015625, 0.0288238525390625, -0.03839111328125, 0.0767822265625, -0.04156494140625, -0.02911376953125, 0.0309906005859375, -0.039337158203125, -0.0287017822265625, 0.00672149658203125, 0.0225067138671875, 0.037322998046875, 0.04510498046875, -0.0452880859375, -0.008941650390625, -0.04083251953125, -0.007556915283203125, 0.015045166015625, -0.017669677734375, 0.031341552734375, 0.035675048828125, -0.00028824806213378906, -0.04254150390625, 0.007659912109375, -0.01241302490234375, 0.02130126953125, -0.0521240234375, 0.0243682861328125, 0.0107269287109375, -0.00714874267578125, -0.0026111602783203125, -0.0494384765625, -0.006072998046875, -0.00298309326171875, -0.07672119140625, 0.0132293701171875, 0.004253387451171875, -0.01094818115234375, 0.052886962890625, 0.05279541015625, -0.0253143310546875, 0.006969451904296875, -0.00978851318359375, -0.009185791015625, 0.0182952880859375, 0.046356201171875, -0.03167724609375, -0.044189453125, -0.0135345458984375, -0.0012989044189453125, -0.0009584426879882812, -0.0233001708984375, -0.00213623046875, -0.0011110305786132812, -0.045562744140625, -0.05194091796875, -0.04608154296875, -0.048553466796875, -0.0186004638671875, 0.0138092041015625, 0.005458831787109375, 0.054443359375, -0.044525146484375, -0.039398193359375, 0.051116943359375, 4.315376281738281e-05, 0.0290985107421875, 0.0168914794921875, 0.03192138671875, -0.004261016845703125, 0.0022640228271484375, 0.00884246826171875, 0.0443115234375, 0.01153564453125, -0.00971221923828125, -0.03668212890625, -0.0506591796875, 0.0026950836181640625, -0.1307373046875, -0.0027313232421875, -0.0104217529296875, 0.03839111328125, -0.0034198760986328125, -0.035186767578125, -0.0006260871887207031, -0.033966064453125, 0.036376953125, -0.0145721435546875, -0.01654052734375, -0.0010690689086914062, 0.0104217529296875, -0.02117919921875, -0.0149383544921875, -0.0198974609375, 0.031463623046875, 0.03631591796875, -0.0114593505859375, -0.032867431640625, 0.0098876953125, -0.0262603759765625, 0.0472412109375, -0.0250244140625, 0.02593994140625, -0.0069580078125, -0.0102691650390625, 0.01197052001953125, -0.02777099609375, 0.0027256011962890625, 0.01560211181640625, -0.0016546249389648438, 0.0141143798828125, 0.0005249977111816406, 0.00385284423828125, -0.06463623046875, 0.00485992431640625, 0.055023193359375, -0.0147552490234375, 0.0634765625, 0.002620697021484375, 0.049591064453125, -0.03985595703125, 0.0352783203125, -0.04168701171875, -0.0357666015625, 0.00696563720703125, 0.0258636474609375, -0.00458526611328125, -0.0153350830078125, 0.034942626953125, 0.018280029296875, -0.0208892822265625, -0.0267181396484375, 0.0474853515625, -0.0265350341796875, -0.036346435546875, -0.02301025390625, -0.038848876953125, -0.019195556640625, -0.04205322265625, -0.06610107421875, -0.033721923828125, 0.031524658203125, 0.08721923828125, -0.03839111328125, 0.008575439453125, -0.0002980232238769531, -0.01398468017578125, -0.0031452178955078125, -0.017547607421875, 0.0254364013671875, 0.027679443359375, 0.00572967529296875, 0.03033447265625, -0.0153656005859375, -0.012939453125, -0.029510498046875, 0.0145721435546875, -0.033538818359375, -0.04888916015625, 0.042266845703125, 0.032867431640625, -0.029876708984375, 0.044189453125, -0.047271728515625, 0.048675537109375, 0.019256591796875, -0.0006532669067382812, 0.028854370 ...
#  Embedding(embedding=[0.021026611328125, 0.00701904296875, -0.0164642333984375, 0.06414794921875, 0.060150146484375, -0.03851318359375, -0.0151519775390625, 0.06781005859375, -0.02606201171875, 0.015380859375, 0.03594970703125, 0.00745391845703125, -0.0005702972412109375, -0.0112152099609375, 0.0149078369140625, 0.039306640625, -0.01580810546875, -0.0171051025390625, 0.0018939971923828125, -0.01141357421875, 0.00939178466796875, 0.0181121826171875, -0.015106201171875, 0.0623779296875, -0.02130126953125, 0.0330810546875, -0.068359375, 0.09185791015625, -0.01097869873046875, 0.017974853515625, 0.0264892578125, -0.0160064697265625, -0.017730712890625, 0.043731689453125, 0.021728515625, 0.0166168212890625, -0.035919189453125, -0.0270538330078125, 0.0391845703125, 0.01303863525390625, -0.047882080078125, -0.01233673095703125, 0.032318115234375, -0.0010805130004882812, 0.01568603515625, -0.03924560546875, -0.031494140625, -0.032440185546875, 0.002567291259765625, 0.05145263671875, -0.0391845703125, 0.01378631591796875, 0.0101776123046875, 0.0399169921875, -0.0953369140625, 0.0009908676147460938, -0.0030269622802734375, 0.0219268798828125, -0.03668212890625, 0.0037059783935546875, 0.0296478271484375, -0.017425537109375, 0.0225830078125, -0.00452423095703125, 0.0006122589111328125, -0.0169830322265625, -0.032867431640625, -0.044586181640625, -0.0491943359375, -0.0106048583984375, 0.03057861328125, 0.027099609375, -0.0214080810546875, 0.01806640625, 0.01192474365234375, -0.01042938232421875, 0.0161285400390625, -0.00241851806640625, -0.016021728515625, -0.052490234375, -0.006439208984375, -0.00772857666015625, 0.0017385482788085938, -0.01369476318359375, -0.00849151611328125, 0.00452423095703125, -0.021209716796875, -0.0421142578125, -0.075927734375, -0.027069091796875, 0.0150299072265625, 0.024139404296875, -0.058837890625, 0.047576904296875, -0.00365447998046875, -0.027801513671875, 0.038848876953125, -0.007061004638671875, 0.007015228271484375, 0.0266571044921875, 0.0054779052734375, -0.0071563720703125, -0.007965087890625, -0.0223236083984375, 0.0723876953125, 0.04510498046875, -0.0224456787109375, -0.060516357421875, -0.0197601318359375, -0.0155487060546875, -0.10205078125, -0.0217132568359375, 0.0089111328125, -0.0026760101318359375, -0.01125335693359375, -0.0099639892578125, -0.02197265625, -0.01788330078125, 0.0081024169921875, 0.007648468017578125, -0.01395416259765625, 0.0112762451171875, 0.0105743408203125, -0.01427459716796875, -0.0249176025390625, 0.01177978515625, 0.042266845703125, 0.00146484375, -0.0616455078125, -0.06805419921875, 0.0177459716796875, -0.04693603515625, 0.0135345458984375, -0.004985809326171875, 0.01476287841796875, 0.01006317138671875, -0.051483154296875, -0.0127410888671875, -0.032745361328125, 0.028228759765625, -0.0341796875, 0.032989501953125, 0.0272979736328125, -0.0167694091796875, 0.01019287109375, -0.053070068359375, -0.0030498504638671875, 0.0160675048828125, -0.024688720703125, 0.026336669921875, 0.002685546875, 0.018829345703125, -0.06170654296875, 0.0301055908203125, -0.01169586181640625, -0.02447509765625, 0.01145172119140625, 0.042144775390625, -0.0233612060546875, -0.029815673828125, 0.01580810546875, -0.007579803466796875, -0.05731201171875, -0.0013179779052734375, 0.032562255859375, -0.002643585205078125, -0.036529541015625, -0.0145263671875, -0.03204345703125, -0.0003120899200439453, -0.004199981689453125, -0.024658203125, -0.053497314453125, 0.01309967041015625, 0.08056640625, -0.0244903564453125, -0.030670166015625, -0.00689697265625, -0.0181121826171875, -0.0192413330078125, -0.043365478515625, 0.00281524658203125, -0.006099700927734375, -0.024566650390625, 0.0178375244140625, -0.0266571044921875, -0.04388427734375, -0.00971221923828125, -0.01904296875, -0.01387786865234375, -0.0595703125, 0.027801513671875, 0.038177490234375, -0.00661468505859375, 0.00835418701171875, -0.0654296875, 0.04931640625, -0.0029315948486328125, 0.01276397705078125, 0.0450439453125, -0.031768798828125, 0. ...
#  Embedding(embedding=[0.040008544921875, 0.00325775146484375, 0.0083770751953125, 0.046722412109375, 0.04949951171875, 0.004482269287109375, 0.0166778564453125, 0.01082611083984375, -0.001068115234375, 0.0227203369140625, 0.08843994140625, 0.0155792236328125, -0.027191162109375, -0.03765869140625, 0.02862548828125, 0.03564453125, -0.0148468017578125, -0.019561767578125, -0.006221771240234375, -0.01183319091796875, -0.005176544189453125, 0.0165863037109375, 0.0303192138671875, 0.06866455078125, -0.0447998046875, 0.02069091796875, -0.0310211181640625, 0.059783935546875, 0.0501708984375, -0.055908203125, 0.005168914794921875, -0.019805908203125, 0.0341796875, -0.0115966796875, 0.023712158203125, 0.070556640625, -0.0233154296875, 0.01044464111328125, 0.036712646484375, 0.019134521484375, -0.01763916015625, 0.0162353515625, 0.007465362548828125, 0.02093505859375, 0.07012939453125, -0.0007810592651367188, -0.0150604248046875, -0.030731201171875, 0.016326904296875, 0.0513916015625, -0.030548095703125, 0.04095458984375, 0.0133209228515625, 0.026458740234375, -0.0229339599609375, -0.0406494140625, 0.0257720947265625, 0.01282501220703125, -0.06005859375, 0.03155517578125, -0.0194091796875, -0.038543701171875, -0.007312774658203125, 0.003948211669921875, -0.0171966552734375, -0.0224151611328125, -0.03216552734375, 0.01099395751953125, 0.017364501953125, 0.0276947021484375, 0.064697265625, 0.03533935546875, 0.0043487548828125, 0.03778076171875, -0.0295257568359375, -0.035552978515625, 0.0009326934814453125, -0.0045318603515625, 0.038055419921875, -0.04278564453125, -0.0184478759765625, -0.0189361572265625, -0.0169677734375, 0.01239013671875, -0.01009368896484375, -0.00726318359375, -0.0616455078125, -0.0185699462890625, 0.0286102294921875, -0.0171051025390625, 0.01538848876953125, 0.0166015625, 0.0165252685546875, -0.008697509765625, 0.0179901123046875, -0.0188446044921875, 0.0257415771484375, 0.03192138671875, 0.00922393798828125, 0.00787353515625, 0.03887939453125, -0.00957489013671875, 0.02032470703125, 0.024688720703125, 0.0255126953125, 0.040557861328125, -0.0218658447265625, -0.0523681640625, -0.01898193359375, -0.006557464599609375, -0.10931396484375, -0.0301666259765625, -0.0242156982421875, 0.0287628173828125, -0.0018033981323242188, 0.00946044921875, -0.04620361328125, -0.0198822021484375, 0.0111083984375, 0.0068206787109375, 0.0302734375, 0.0200653076171875, -0.0323486328125, -0.056060791015625, -0.00699615478515625, -0.0234832763671875, -0.02081298828125, -0.01042938232421875, -0.022979736328125, -0.0599365234375, -0.01751708984375, -0.045166015625, 0.01284027099609375, -0.01261138916015625, -0.0233612060546875, 0.0251312255859375, -0.036468505859375, 0.0030727386474609375, -0.0215301513671875, 0.0100555419921875, -0.0108642578125, -0.062744140625, 0.03167724609375, -0.027252197265625, 0.0298004150390625, 0.0190582275390625, 0.0216522216796875, 0.00640869140625, -0.029541015625, -0.022552490234375, -0.00917816162109375, 0.01267242431640625, -0.0281219482421875, 0.02978515625, 0.0033130645751953125, -0.0239105224609375, 0.016021728515625, 0.033905029296875, -0.0107269287109375, -0.00917816162109375, 0.038177490234375, 0.0017099380493164062, -0.0130767822265625, -0.007770538330078125, 0.04315185546875, 0.00958251953125, -0.0136871337890625, -0.0443115234375, -0.03509521484375, -0.025787353515625, -0.059661865234375, -0.0176544189453125, -0.029083251953125, 0.033538818359375, 0.060516357421875, -0.046478271484375, -0.0029735565185546875, 0.0035152435302734375, -0.04693603515625, -0.0477294921875, 0.002498626708984375, 0.032501220703125, 0.004180908203125, -0.0149993896484375, -0.0126495361328125, 0.0295562744140625, -0.045135498046875, 0.035858154296875, 0.019744873046875, 0.002986907958984375, -0.06622314453125, 0.0281219482421875, 0.0379638671875, -0.042724609375, 0.022064208984375, -0.0482177734375, 0.057861328125, 0.0212860107421875, 0.00751495361328125, 0.037017822265625, -0.02630615234375, 0.00537872314453125, 0.05618286132 ...
#  Embedding(embedding=[0.033111572265625, 0.01325225830078125, 0.0268096923828125, 0.06494140625, 0.034942626953125, 0.009918212890625, 0.0009417533874511719, 0.04119873046875, 0.01465606689453125, 0.039825439453125, 0.07196044921875, -0.0169525146484375, 0.01242828369140625, -0.03619384765625, 0.037322998046875, 0.0264739990234375, 0.0247039794921875, -0.0164642333984375, 0.0144500732421875, -0.0029468536376953125, 0.03173828125, 0.0252227783203125, 0.0148468017578125, 0.0391845703125, -0.03265380859375, -0.00948333740234375, -0.0372314453125, 0.0174102783203125, 0.00624847412109375, -0.047332763671875, 0.00310516357421875, -0.024017333984375, -0.0023345947265625, 0.017120361328125, 0.0015344619750976562, 0.0882568359375, -0.001605987548828125, -0.0262908935546875, 0.05426025390625, 0.007678985595703125, -0.01532745361328125, 0.0625, -0.00655364990234375, 0.0208740234375, 0.076416015625, -0.037353515625, -0.049285888671875, -0.04095458984375, 0.005039215087890625, -0.0005278587341308594, -0.002788543701171875, 0.03179931640625, 0.0030517578125, 0.01055908203125, -0.01180267333984375, -0.0504150390625, -0.0107421875, 0.0242462158203125, -0.0430908203125, 0.005443572998046875, -0.04327392578125, -0.0222015380859375, -0.017303466796875, -0.012786865234375, -0.008026123046875, -0.0088653564453125, -0.031402587890625, 0.0258941650390625, 0.020233154296875, 0.0163726806640625, 0.07373046875, 0.04876708984375, -0.0445556640625, 0.0267181396484375, 0.018341064453125, -0.033294677734375, 0.01458740234375, 0.010223388671875, -0.01244354248046875, -0.024017333984375, 0.0020999908447265625, -0.0299072265625, -0.030914306640625, 0.007472991943359375, -0.0228271484375, -0.0015802383422851562, -0.04437255859375, -0.0267486572265625, 0.01629638671875, -0.01690673828125, -0.024444580078125, -0.017059326171875, 0.01690673828125, 0.029449462890625, 0.016326904296875, 0.0192718505859375, 0.002689361572265625, 0.0335693359375, 0.0249176025390625, -0.003688812255859375, 0.049346923828125, 0.00223541259765625, -0.0092620849609375, 0.0213470458984375, 0.05694580078125, 0.03375244140625, 0.00220489501953125, -0.015167236328125, -0.033447265625, -0.0243072509765625, -0.0791015625, -0.0211334228515625, -0.023773193359375, -0.01202392578125, 0.01337432861328125, 0.0153656005859375, -0.0305938720703125, -0.033782958984375, 0.007266998291015625, -0.0114898681640625, 0.005916595458984375, -0.00223541259765625, -0.02557373046875, -0.0304718017578125, 0.006771087646484375, -0.07464599609375, 0.002727508544921875, 0.0006012916564941406, -0.03887939453125, -0.05584716796875, 0.01873779296875, -0.0269775390625, 0.03106689453125, -0.01617431640625, -0.01384735107421875, 0.00984954833984375, -0.05224609375, 0.01285552978515625, -0.00897979736328125, -0.00787353515625, 0.016021728515625, -0.0190582275390625, 0.0089569091796875, -0.0292205810546875, -0.0013265609741210938, -0.033294677734375, -0.0025787353515625, 0.040374755859375, -0.0391845703125, 0.050201416015625, -0.03057861328125, 0.02337646484375, -0.006500244140625, 0.0125579833984375, -0.0207366943359375, 0.01129150390625, 0.032745361328125, 0.038818359375, -0.00397491455078125, -0.0200958251953125, 0.055877685546875, 0.0173492431640625, -0.07257080078125, -0.0302886962890625, -0.0086517333984375, -0.01139068603515625, -0.020538330078125, -0.006160736083984375, -0.03302001953125, -0.01337432861328125, -0.09185791015625, -0.0198974609375, -0.0423583984375, 0.01629638671875, 0.03411865234375, -0.0284576416015625, -0.009796142578125, -0.05224609375, -0.045257568359375, 0.0181121826171875, -0.0090789794921875, 0.0295257568359375, 0.0227203369140625, 0.007320404052734375, 0.0098419189453125, 0.043365478515625, -0.048980712890625, 0.01468658447265625, -0.004970550537109375, 0.00203704833984375, -0.052581787109375, -0.001331329345703125, 0.0193023681640625, -0.003437042236328125, 0.027252197265625, -0.041900634765625, 0.07098388671875, 0.024017333984375, -0.0246734619140625, 0.03399658203125, -0.0076904296875, 0.0 ...
# ...
#  Embedding(embedding=[0.07232666015625, 0.02130126953125, -0.005840301513671875, 0.055572509765625, 0.0546875, -0.0198822021484375, 0.0450439453125, 0.0797119140625, -0.0518798828125, 0.021942138671875, 0.059234619140625, -0.0110321044921875, -0.0267181396484375, -0.010284423828125, 0.008697509765625, 0.016387939453125, 0.005802154541015625, -0.059844970703125, 0.01442718505859375, -0.0478515625, 0.031097412109375, 0.04742431640625, 0.006130218505859375, 0.040802001953125, 0.0102081298828125, 0.05438232421875, -0.0219268798828125, 0.048370361328125, -0.03485107421875, -0.03875732421875, 0.0018587112426757812, -0.020263671875, 0.0023746490478515625, -0.006557464599609375, 0.051788330078125, 0.04638671875, 0.01800537109375, 0.030303955078125, 0.02203369140625, 0.02203369140625, 0.01349639892578125, 0.01393890380859375, 0.0618896484375, 0.044952392578125, 0.008331298828125, -0.03533935546875, -0.041473388671875, -0.043243408203125, 0.0192718505859375, 0.054443359375, -0.02197265625, 0.03228759765625, 0.021026611328125, -0.0004973411560058594, 0.006114959716796875, -0.0205535888671875, 0.01129150390625, 0.0008254051208496094, -0.055511474609375, 0.0291290283203125, 0.023406982421875, -0.021240234375, 0.0019664764404296875, 0.034423828125, 0.0108489990234375, -0.03271484375, -0.058685302734375, -0.0180816650390625, 0.01125335693359375, 0.046600341796875, 0.070068359375, 0.03131103515625, -0.033355712890625, 0.014984130859375, 0.0006804466247558594, -0.06878662109375, -0.01299285888671875, 0.022705078125, 0.01393890380859375, -0.041107177734375, 0.0105133056640625, -0.033782958984375, 0.0164794921875, 0.040771484375, -0.0333251953125, -0.01898193359375, -0.019683837890625, -0.0194854736328125, 0.01007843017578125, 0.01145172119140625, -0.02294921875, 0.01247406005859375, 0.0024585723876953125, 0.0243988037109375, 0.033416748046875, 0.0258026123046875, 0.0266571044921875, 0.023284912109375, 0.0297393798828125, -0.0156707763671875, 0.0036296844482421875, -0.054656982421875, -0.0229949951171875, 0.04278564453125, 0.0266571044921875, -0.02191162109375, -0.0245819091796875, -0.0384521484375, -0.032440185546875, -0.01910400390625, -0.1083984375, -0.013763427734375, -0.00628662109375, 0.036590576171875, -0.033477783203125, -0.0049896240234375, -0.00833892822265625, 0.00998687744140625, 0.0083465576171875, 0.0088043212890625, -0.0179901123046875, -0.01015472412109375, -0.01560211181640625, -5.78761100769043e-05, -0.0232391357421875, -0.00916290283203125, -0.0301055908203125, -0.0321044921875, -0.0203399658203125, -0.08148193359375, -0.0223236083984375, -0.0203399658203125, -0.01473236083984375, -0.0283966064453125, -0.005397796630859375, 0.00432586669921875, -0.05499267578125, 0.0089111328125, 0.00707244873046875, 0.034423828125, 0.033355712890625, -0.00969696044921875, -0.0128326416015625, 0.00051116943359375, 0.035186767578125, -0.02117919921875, -0.0163116455078125, 0.0201416015625, -0.019989013671875, 0.01435089111328125, -0.0294952392578125, 0.01091766357421875, -0.024871826171875, 0.004833221435546875, -0.0169677734375, -0.0213623046875, 0.0200653076171875, 0.01271820068359375, -0.031646728515625, -0.0201263427734375, 0.0311279296875, 0.03564453125, -0.01488494873046875, -0.0258331298828125, 0.0262603759765625, -0.0177459716796875, -0.03765869140625, -0.046905517578125, -0.06427001953125, -0.0306854248046875, -0.05718994140625, -0.043487548828125, -0.042388916015625, 0.061065673828125, 0.08624267578125, -0.020233154296875, -0.059173583984375, -0.00559234619140625, -0.03302001953125, -0.039306640625, -0.044158935546875, -0.04046630859375, -0.024017333984375, -0.02154541015625, 0.00861358642578125, 0.01255035400390625, -0.03765869140625, 0.01494598388671875, 0.01497650146484375, -0.0210418701171875, -0.050994873046875, 0.0159759521484375, 0.043548583984375, -0.0292816162109375, -0.03466796875, -0.0220947265625, 0.033599853515625, 0.0230560302734375, 0.0032749176025390625, 0.05670166015625, 0.01092529296875, 0.002902984619140625, 0.05551 ...
#  Embedding(embedding=[0.036163330078125, -0.00045371055603027344, 0.026641845703125, 0.031829833984375, 0.034149169921875, -0.0537109375, -0.0210723876953125, 0.047607421875, -0.05560302734375, -0.005916595458984375, 0.031707763671875, -0.023590087890625, -0.020782470703125, -0.07470703125, 0.01052093505859375, 0.038360595703125, 0.01849365234375, -0.0760498046875, 0.05206298828125, -0.03271484375, 0.015289306640625, 0.033050537109375, 0.0290679931640625, 0.07952880859375, -0.0305328369140625, 0.0291748046875, -0.0290985107421875, 0.09503173828125, 0.0087890625, -0.034912109375, 0.005512237548828125, -0.0213470458984375, 0.0028362274169921875, 0.049407958984375, -0.009918212890625, 0.01123809814453125, 0.0111236572265625, -0.019927978515625, 0.0277252197265625, -0.0102996826171875, 0.003284454345703125, -0.02886962890625, 0.05804443359375, 0.042999267578125, 0.0297393798828125, -0.0293731689453125, -0.0411376953125, -0.02984619140625, -0.00897979736328125, 0.0670166015625, -0.0364990234375, 0.035125732421875, 0.004428863525390625, -0.0093536376953125, -0.042236328125, -0.047332763671875, -0.005908966064453125, -0.03875732421875, -0.07342529296875, 0.06787109375, -0.00402069091796875, 0.00627899169921875, 0.050537109375, 0.0226593017578125, -0.033233642578125, 0.00955963134765625, -0.056549072265625, 0.0222320556640625, 0.0022411346435546875, 0.039459228515625, 0.04339599609375, 0.04888916015625, -0.051300048828125, 0.031951904296875, 0.016021728515625, -0.07110595703125, -0.06646728515625, 0.032562255859375, 0.0215301513671875, -0.056976318359375, -0.0182647705078125, 0.0086517333984375, 0.01174163818359375, 0.028472900390625, -0.051483154296875, -0.0404052734375, 0.0256195068359375, -0.00304412841796875, -0.00794219970703125, -0.00772857666015625, 0.006504058837890625, 0.023040771484375, -0.0159149169921875, -0.0273590087890625, 0.0226287841796875, 0.0218353271484375, 0.049285888671875, 0.041961669921875, 0.048583984375, 0.020904541015625, 0.0275726318359375, -0.0295562744140625, -0.04437255859375, -0.0170135498046875, -0.0021228790283203125, 0.01367950439453125, -0.00795745849609375, -0.0084991455078125, -0.060791015625, -0.041748046875, -0.1268310546875, -0.00235748291015625, 0.032684326171875, 0.033050537109375, -0.016510009765625, -0.022918701171875, 0.024017333984375, 0.0116119384765625, 0.040252685546875, 0.003551483154296875, 0.0232391357421875, -0.036590576171875, -0.037506103515625, -0.03411865234375, 0.0206756591796875, -0.05523681640625, -0.054107666015625, -0.015655517578125, -0.0177154541015625, -0.05523681640625, 0.0142364501953125, -0.00014853477478027344, -0.001667022705078125, -0.02764892578125, 0.0216522216796875, -0.0249786376953125, -0.02911376953125, -0.0017366409301757812, -0.01336669921875, 0.0017862319946289062, 0.01861572265625, -0.016021728515625, -0.030517578125, -0.03497314453125, -0.018768310546875, -0.03167724609375, 0.01186370849609375, 0.0225830078125, -0.0428466796875, -0.0187530517578125, -0.017120361328125, -0.0238494873046875, -0.02972412109375, 0.00428009033203125, 0.004150390625, -0.020599365234375, 0.00402069091796875, 0.00916290283203125, -0.00673675537109375, -0.037261962890625, 0.045135498046875, 0.04241943359375, -0.05755615234375, -0.0227203369140625, 0.0183258056640625, 0.002044677734375, -0.05938720703125, -0.033447265625, -0.0404052734375, -0.0247955322265625, -0.084716796875, -0.08746337890625, -0.02044677734375, 0.00693511962890625, 0.0516357421875, -0.036773681640625, -0.08917236328125, -0.027923583984375, -0.027923583984375, -0.031036376953125, -0.01715087890625, 0.0196685791015625, -0.0011425018310546875, -0.0504150390625, -0.00860595703125, 0.057281494140625, -0.04229736328125, -0.0171356201171875, 0.00946807861328125, -0.05694580078125, -0.04840087890625, 0.046234130859375, 0.0244903564453125, 0.0026035308837890625, 0.032501220703125, -0.025177001953125, 0.0482177734375, 0.031951904296875, 0.0123138427734375, 0.03375244140625, 0.032470703125, 0.0005788803100585938, 0.03329 ...
#  Embedding(embedding=[0.0272979736328125, 0.0174560546875, -0.0294189453125, -0.0120697021484375, 0.0323486328125, -0.032867431640625, -0.0175933837890625, 0.0207366943359375, -0.040679931640625, 0.01538848876953125, 0.038787841796875, -0.0203704833984375, -0.01513671875, -0.00470733642578125, 0.054046630859375, -0.00582122802734375, -0.01568603515625, -0.05841064453125, 0.0261688232421875, -0.0204925537109375, -0.025543212890625, 0.01119232177734375, 0.01326751708984375, 0.0189208984375, -0.02813720703125, 0.06268310546875, -0.0012035369873046875, 0.0662841796875, 0.018585205078125, -0.01971435546875, -0.0135955810546875, -0.0255889892578125, -0.003910064697265625, 0.00414276123046875, 0.048736572265625, -0.0190887451171875, -0.010162353515625, -0.057708740234375, -0.01480865478515625, -0.0279083251953125, -0.0181121826171875, -0.037994384765625, 0.009490966796875, 0.00930023193359375, 0.031158447265625, -0.016021728515625, -0.0292205810546875, 0.007389068603515625, 0.03399658203125, 0.024169921875, -0.0435791015625, 0.05352783203125, -0.035888671875, 0.049072265625, -0.057891845703125, -0.0299530029296875, -0.0270843505859375, 0.023590087890625, 0.039154052734375, 0.007476806640625, 0.01126861572265625, 0.01128387451171875, 0.01061248779296875, 0.038177490234375, -0.006687164306640625, 0.01094818115234375, -0.05303955078125, 0.0272674560546875, -0.0133056640625, 0.0300140380859375, 0.044830322265625, 0.023101806640625, -0.0105133056640625, -0.0165252685546875, 0.01922607421875, 0.042999267578125, -0.0111846923828125, -0.00865936279296875, -0.02691650390625, -0.05426025390625, -0.01189422607421875, 0.0263214111328125, -0.01172637939453125, -0.0239105224609375, 0.0090179443359375, -0.0731201171875, 0.0013494491577148438, -0.01024627685546875, 0.01922607421875, -0.02783203125, 0.0134124755859375, 0.0092010498046875, -0.08367919921875, -0.0014333724975585938, 0.045074462890625, -0.0174407958984375, 0.01251220703125, 0.028350830078125, 0.02703857421875, -0.00742340087890625, 0.044097900390625, -0.040924072265625, -0.0279083251953125, -0.031524658203125, 0.03753662109375, 0.03021240234375, -0.042694091796875, 0.0289154052734375, -0.035675048828125, -0.024688720703125, -0.1070556640625, -0.00634765625, 0.039215087890625, 0.0023288726806640625, 0.006908416748046875, -0.0014858245849609375, 0.01519012451171875, -0.03924560546875, 0.050445556640625, 0.02716064453125, -0.0184478759765625, -0.0279998779296875, 0.010894775390625, 0.006011962890625, 0.005504608154296875, 0.0259552001953125, 0.0018310546875, 0.01551055908203125, -0.0162353515625, 0.021209716796875, -0.0241546630859375, 0.0073089599609375, 0.0125579833984375, -0.050689697265625, 0.00628662109375, -0.0179290771484375, -0.080810546875, 0.0202484130859375, -0.004734039306640625, 0.0660400390625, -0.001758575439453125, 0.001712799072265625, 0.00911712646484375, -0.016571044921875, -0.0011262893676757812, -0.01397705078125, -0.020660400390625, -0.0048675537109375, -0.04974365234375, -0.04803466796875, 0.00604248046875, -0.0181884765625, 0.004390716552734375, -0.02032470703125, 0.01837158203125, -0.034820556640625, -0.01195526123046875, 0.01238250732421875, -0.031494140625, -0.001850128173828125, 0.00926971435546875, -0.023101806640625, 0.005680084228515625, 0.0311126708984375, 0.0276947021484375, -0.004421234130859375, -0.0273590087890625, -0.011383056640625, -0.042205810546875, 0.0017337799072265625, -0.038543701171875, -0.03912353515625, 0.02423095703125, -0.01123046875, 0.0141143798828125, -0.00946044921875, 0.0006289482116699219, -0.003978729248046875, 0.0011157989501953125, -0.0290679931640625, 0.01629638671875, 0.05999755859375, -0.0731201171875, -0.0205078125, 0.0262908935546875, 0.021087646484375, -0.00266265869140625, 0.0304412841796875, 0.015869140625, 0.0085601806640625, -0.03759765625, 0.00402069091796875, 0.047271728515625, 0.010528564453125, 0.02178955078125, -0.036376953125, 0.041351318359375, 0.010711669921875, -0.01297760009765625, 0.01226043701171875, 0.0145492 ...

# %%
# verify embeddings
print(f"Generated {len(embeddings)} embeddings")
print(f"Each embedding has {len(embeddings[0])} dimensions")
# Out:
# Generated 35 embeddings
# Each embedding has 1536 dimensions

# %%
import numpy as np, matplotlib.pyplot as plt
from sklearn.decomposition import PCA

X = np.array(embeddings)
xy = PCA(n_components=2).fit_transform(X)

fig, ax = plt.subplots(figsize=(8, 6))
ax.scatter(*xy.T, s=90, color="#3b7cd3", edgecolor="white", linewidth=1.5)

for i, (x, y) in enumerate(xy):
    ax.annotate(
        f"C{i + 1}",
        (x, y),
        textcoords="offset points",
        xytext=(0, 10),
        ha="center",
        fontsize=8,
        color="#26456f",
    )

ax.set_title(f"{len(chunks)} chunk embeddings (PCA)", loc="left")
ax.set_xlabel("PC1")
ax.set_ylabel("PC2")
plt.show()

# %%
# could use tsne
import numpy as np, matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

X = np.array(embeddings)
xy = PCA(n_components=2).fit_transform(X)

# cluster on the full embeddings, not the 2D projection — PCA is only for display
labels = KMeans(n_clusters=2, n_init=10, random_state=0).fit_predict(X)

COLORS = ["#2a78d6", "#eb6834"]
MARKERS = ["o", "s"]

fig, ax = plt.subplots(figsize=(8, 6))

for k in (0, 1):
    m = labels == k
    ax.scatter(
        *xy[m].T,
        s=110,
        color=COLORS[k],
        marker=MARKERS[k],
        edgecolor="white",
        linewidth=2,
        label=f"Cluster {k + 1}  ({m.sum()} chunks)",
    )

for i, (x, y) in enumerate(xy):
    ax.annotate(
        f"C{i + 1}",
        (x, y),
        textcoords="offset points",
        xytext=(0, 11),
        ha="center",
        fontsize=8,
        color="#52514e",
    )

ax.set_title(f"{len(chunks)} chunk embeddings, 2 clusters (PCA)", loc="left")
ax.set_xlabel("PC1")
ax.set_ylabel("PC2")
ax.legend(frameon=False, loc="best")
ax.grid(alpha=0.15)
ax.set_axisbelow(True)
plt.show()

# %%
import textwrap

def describe_cluster(cluster_chunks, k):
    joined = "\n\n---\n\n".join(cluster_chunks)
    response = client.chat.completions.create(
        model="gpt-4.1-mini",
        messages=[
            {
                "role": "system",
                "content": (
                    "You analyze clusters of text chunks from a single document. "
                    "Given the chunks in one cluster, reply with exactly two lines:\n"
                    "LABEL: <2-4 word theme>\n"
                    "SUMMARY: <1-2 sentences on what unites these chunks>"
                ),
            },
            {
                "role": "user",
                "content": f"Cluster {k + 1} contains {len(cluster_chunks)} chunks:\n\n{joined}",
            },
        ],
        temperature=0.2,
    )
    text = response.choices[0].message.content.strip()

    label, summary = f"Cluster {k + 1}", text
    for line in text.splitlines():
        if line.startswith("LABEL:"):
            label = line.removeprefix("LABEL:").strip()
        elif line.startswith("SUMMARY:"):
            summary = line.removeprefix("SUMMARY:").strip()
    return label, summary


cluster_info = {}
for k in (0, 1):
    idx = np.where(labels == k)[0]
    label, summary = describe_cluster([chunks[i] for i in idx], k)
    cluster_info[k] = {"label": label, "summary": summary, "idx": idx}

    print(f"=== Cluster {k + 1}: {label} ({len(idx)} chunks) ===")
    print(textwrap.fill(summary, 88))
    print("chunks:", ", ".join(f"C{i + 1}" for i in idx), "\n")
# Out:
# === Cluster 1: Netflix Company Culture (17 chunks) ===
# These chunks describe Netflix's unique company culture centered on high performance,
# freedom in decision-making, bold innovation, and continuous improvement. The culture
# emphasizes empowering talented individuals, embracing discomfort for growth, supporting
# diverse artistic expression, and striving for excellence.
# chunks: C1, C2, C3, C4, C7, C9, C17, C20, C24, C25, C27, C28, C29, C30, C31, C32, C35
#
# === Cluster 2: Dream Team Culture (18 chunks) ===
# These chunks emphasize building a high-performance workplace modeled on a professional
# sports team, valuing selflessness, creativity, courage, and inclusion. The focus is on
# accountability, extraordinary candor, informed decision-making, and prioritizing people
# over process to foster trust, innovation, and long-term success.
# chunks: C5, C6, C8, C10, C11, C12, C13, C14, C15, C16, C18, C19, C21, C22, C23, C26, C33, C34

# %%
import numpy as np, matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

X = np.array(embeddings)
xyz = PCA(n_components=3).fit_transform(X)

labels = KMeans(n_clusters=2, n_init=10, random_state=0).fit_predict(X)

COLORS = ["#2a78d6", "#eb6834"]
MARKERS = ["o", "s"]

fig = plt.figure(figsize=(9, 7))
ax = fig.add_subplot(111, projection="3d")

for k in (0, 1):
    m = labels == k
    ax.scatter(
        *xyz[m].T,
        s=110,
        color=COLORS[k],
        marker=MARKERS[k],
        edgecolor="white",
        linewidth=2,
        depthshade=False,          # keep cluster color constant with depth
        label=f"{cluster_info[k]['label']}  ({m.sum()} chunks)",
    )

for i, (x, y, z) in enumerate(xyz):
    ax.text(x, y, z, f"  C{i + 1}", fontsize=7, color="#52514e")

ax.set_title(f"{len(chunks)} chunk embeddings, 2 clusters (PCA 3D)", loc="left")
ax.set_xlabel("PC1")
ax.set_ylabel("PC2")
ax.set_zlabel("PC3")
ax.legend(frameon=False, loc="upper left")
ax.view_init(elev=22, azim=-58)   # tweak to find a readable angle
plt.tight_layout()
plt.show()

# %%
import numpy as np, textwrap
import plotly.graph_objects as go
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
import nbformat, plotly.io._renderers as _r
_r.nbformat = nbformat


X = np.array(embeddings)
xyz = PCA(n_components=3).fit_transform(X)
labels = KMeans(n_clusters=2, n_init=10, random_state=0).fit_predict(X)

COLORS = ["#2a78d6", "#eb6834"]
SYMBOLS = ["circle", "square"]

fig = go.Figure()

for k in (0, 1):
    idx = np.where(labels == k)[0]
    hover = [
        "<br>".join(textwrap.wrap(f"C{i + 1}: {chunks[i][:220]}…", 60)) for i in idx
    ]
    name = cluster_info[k]["label"] if "cluster_info" in dir() else f"Cluster {k + 1}"

    fig.add_trace(
        go.Scatter3d(
            x=xyz[idx, 0], y=xyz[idx, 1], z=xyz[idx, 2],
            mode="markers+text",
            marker=dict(
                size=8,
                color=COLORS[k],
                symbol=SYMBOLS[k],
                line=dict(color="white", width=2),
            ),
            text=[f"C{i + 1}" for i in idx],
            textposition="top center",
            textfont=dict(size=9, color="#52514e"),
            hovertext=hover,
            hoverinfo="text",
            name=f"{name} ({len(idx)} chunks)",
        )
    )

fig.update_layout(
    title=dict(text=f"{len(chunks)} chunk embeddings, 2 clusters (PCA 3D)", x=0.02),
    scene=dict(xaxis_title="PC1", yaxis_title="PC2", zaxis_title="PC3"),
    legend=dict(orientation="h", y=1.02, yanchor="bottom", x=0),
    margin=dict(l=0, r=0, t=60, b=0),
    height=650,
    template="plotly_white",
)
fig.show()

# %% [markdown]
# ## Step 5: Initialize ChromaDB and Store Vectors

# %%
import chromadb

# Initialize ChromaDB client (persistent storage)
chroma_client = chromadb.PersistentClient(path = "./chroma_db")

# Initialize ChromaDB client (in-memory storage)
# chroma_client = chromadb.Client()

collection = chroma_client.get_or_create_collection(name = "netflix_culture")

# Empty the collection before adding new data (for testing purposes)
if collection.get()["ids"]:
    collection.delete(collection.get()["ids"])

pprint(collection.get())
# Out:
# {'data': None,
#  'documents': [],
#  'embeddings': None,
#  'ids': [],
#  'included': ['metadatas', 'documents'],
#  'metadatas': [],
#  'uris': None}

# %%
# Prepare data for storage
ids = [f"chunk_{i}" for i in range(len(chunks))]
metadatas = [{"source":"netflix_culture", "chunk_index": i} for i in range(len(chunks))]

# Adding data to chromadb
collection.add(
    ids=ids,
    embeddings=embeddings,
    documents=chunks,
    metadatas=metadatas
)

pprint(collection.get())
# Out:
# {'data': None,
#  'documents': ['The Best Work of Our Lives\n'
#                'CULTURE MEMO\n'
#                'At Netflix, we aspire to entertain the world, thrilling '
#                'audiences everywhere. To do that, we’ve\n'
#                'developed an unusual company culture focused on excellence, '
#                'and creating an environment\n'
#                'where talented people can thrive — lifting ourselves, each '
#                'other and our audiences higher and\n'
#                'higher. This document is about that culture, which is based on '
#                'four core principles:\n'
#                '● The Dream Team: We aim only to have high performers at '
#                'Netflix — people who are',
#                'have high performers at Netflix — people who are\n'
#                'great at what they do, and even better at working together.\n'
#                '● People over Process: You get better outcomes when employees '
#                'have the information\n'
#                'and freedom to make decisions for themselves. We hire '
#                'unusually responsible people\n'
#                'who thrive on this openness and freedom.\n'
#                '● Uncomfortably Exciting: To entertain the world, we need to '
#                'be bold and ambitious.\n'
#                'That means embracing the thrill of what’s next — even when '
#                'it’s uncomfortable.',
#                'll of what’s next — even when it’s uncomfortable.\n'
#                '● Great and Always Better: We often say Netflix sucks today '
#                'compared to where we can\n'
#                'be tomorrow. We need the self-awareness to understand what '
#                'should be better, and\n'
#                'the discipline and resilience to get there.\n'
#                'While we don’t always live up to these principles, most people '
#                'who join Netflix are pleasantly\n'
#                'surprised by how great their colleagues are and the way we '
#                'empower people at every level.',
#                'are and the way we empower people at every level.\n'
#                'As our business grows and evolves, our culture (and this '
#                'document) will, too. What won’t\n'
#                'change is our focus on excellence, and our determination to '
#                'ensure that Netflix remains a\n'
#                'place where great people can do the best work of their lives. '
#                'If this sounds exciting, you’ll\n'
#                'probably love it here. But Netflix is not for everyone, so '
#                'please read on.\n'
#                'THE DREAM TEAM',
#                't for everyone, so please read on.\n'
#                'THE DREAM TEAM\n'
#                'We believe that what makes a fantastic workplace isn’t a great '
#                'office or free meals and\n'
#                'massages — although we have some nice perks. It’s the people. '
#                'Imagine working alongside\n'
#                'stunning colleagues who are great at what they do, and even '
#                'better at working together. It’s\n'
#                'why we model ourselves on a professional sports team, not a '
#                'family. Families are about\n'
#                'unconditional love. They can also be dysfunctional, as anyone '
#                'who’s watched Ozark or',
#                'e dysfunctional, as anyone who’s watched Ozark or\n'
#                'Wednesday knows. Professional sports teams, on the other hand, '
#                'focus on performance and\n'
#                'picking the right person for every position, even when that '
#                'means swapping out someone\n'
#                'they love for a better player.\n'
#                'While every member of our Dream Team has different skills, we '
#                'look for common strengths\n'
#                'that make us better together. These are the values we value:\n'
#                '● Selflessness — you are humble when searching for the best '
#                'ideas; you seek what’s',
#                'hen searching for the best ideas; you seek what’s\n'
#                'best for Netflix, not yourself or your team; you take time to '
#                'help others succeed.\n'
#                '● Judgment — you look beyond short term fixes in favor of long '
#                'term solutions; you\n'
#                'make wise decisions despite ambiguity; you use data to inform '
#                'your intuition.\n'
#                '● Candor — you willingly receive and give feedback; you are '
#                'open about what’s working\n'
#                'and what needs to improve; you admit mistakes openly and share '
#                'learnings widely.',
#                'admit mistakes openly and share learnings widely.\n'
#                '● Creativity — you welcome new ideas; you are passionate and '
#                'persistent in pursuit of\n'
#                'more innovative solutions; you value artistic expression.\n'
#                '● Courage — you are vulnerable in search for the truth; you '
#                'are willing to risk failure, or\n'
#                'challenge the status quo, in the pursuit of excellence.\n'
#                '● Inclusion — you recognize your biases and work to counteract '
#                'them; you try to ensure',
#                'es and work to counteract them; you try to ensure\n'
#                'everyone at Netflix can do their best work, whatever their '
#                'culture, identity or\n'
#                'background.\n'
#                '● Curiosity — you learn rapidly and eagerly; you are more '
#                'interested in other people’s\n'
#                'ideas than your own; you’re humble about what you don’t yet '
#                'know.\n'
#                '● Resilience — you quickly adapt to changing circumstances; '
#                'you make tough decisions\n'
#                'without agonizing or long delay; you embrace a hard challenge.',
#                'zing or long delay; you embrace a hard challenge.\n'
#                'It’s easy to talk about values and harder to live by them. We '
#                'all work hard to keep each other\n'
#                'accountable for upholding these standards, especially our '
#                'leaders, because excellence and\n'
#                'honesty go hand in hand. It’s why we invest in strong '
#                'professional relationships that build trust\n'
#                'and help people assume good intent. This, in turn, enables us '
#                'to practice extraordinary',
#                'is, in turn, enables us to practice extraordinary\n'
#                'candor — ensuring constructive feedback is part of our '
#                'everyday work (like brushing your\n'
#                'teeth). It takes courage and vulnerability to ask someone how '
#                'you could do better, or to seek\n'
#                'alternative opinions about the best way forward, and integrity '
#                'only to say things about a\n'
#                'colleague that you’re willing to share with them directly. '
#                'This is especially true when you’re',
#                'hem directly. This is especially true when you’re\n'
#                'giving feedback to someone more senior or from a different '
#                'background, or if you come from\n'
#                'a culture or company where deference is the norm. But '
#                'extraordinary candor helps us improve\n'
#                'faster as individuals and a company.\n'
#                'Since a high performer in any role is many times more '
#                'effective than the average employee,\n'
#                'our Dream Team is driven by performance — not seniority, '
#                'tenure or unconditional loyalty. It’s',
#                'seniority, tenure or unconditional loyalty. It’s\n'
#                'also why we focus on maintaining a high performance culture. '
#                'To recruit and retain stunning\n'
#                'colleagues, we pay personal top of market for the role and '
#                'location — a judgment about what\n'
#                'that person could make in a similar role at another company, '
#                'and what we would pay to keep\n'
#                'or replace them. We expect leaders to be strong developers of '
#                'talent. And to ensure they have',
#                'ong developers of talent. And to ensure they have\n'
#                'the right player at every position, we ask them to apply what '
#                'we call the “keeper test”\n'
#                '1 —\n'
#                'asking “if X wanted to leave, would I fight to keep them?” Or '
#                '“knowing everything I know\n'
#                'today, would I hire X again?” If the answer is no, we believe '
#                'it’s fairer to everyone to part ways\n'
#                'quickly.\n'
#                '1 The “keeper test” name came from our co-founder, Reed '
#                'Hastings, who remembers catching a fish as a\n'
#                'child and his dad saying, “That’s a keeper, Reed!”',
#                'hild and his dad saying, “That’s a keeper, Reed!”\n'
#                'In the abstract, the keeper test can sound scary. In reality, '
#                'we encourage everyone to speak to\n'
#                'their managers about what’s going well and what’s not on a '
#                'regular basis. This helps avoid\n'
#                'surprises. Managers also evaluate team members on their whole '
#                'record, rather than focusing\n'
#                'on the mistakes or bets that didn’t pay off. On the Dream '
#                'Team, you need people who',
#                't pay off. On the Dream Team, you need people who\n'
#                'challenge the status quo and try new things. So we stick with '
#                'employees through short-term\n'
#                'bumps.\n'
#                'No matter how brilliant someone may be, there’s no place in '
#                'our Dream Team for people who\n'
#                'don’t treat their colleagues with decency and respect. When '
#                'you have talented people who\n'
#                'work well together — trusting each other’s intentions and '
#                'respecting their differences — it\n'
#                'makes everyone more successful.\n'
#                'PEOPLE OVER PROCESS',
#                'kes everyone more successful.\n'
#                'PEOPLE OVER PROCESS\n'
#                'Many of us have worked at companies where decisions were made '
#                'top down, there was little\n'
#                'transparency and it felt hard to make a difference — or even '
#                'get basic things done. At Netflix,\n'
#                'we aim to inspire and empower more than just manage because '
#                'people can have a greater\n'
#                'impact when they’re free to make decisions about their own '
#                'work.\n'
#                'As part of this, we strive to develop good decision-making '
#                'muscles at every level of the',
#                'ood decision-making muscles at every level of the\n'
#                'company, priding ourselves on how few, not how many, decisions '
#                'senior leaders make. We\n'
#                'expect managers to practice context not control — giving their '
#                'teams the context and clarity\n'
#                'needed to make good decisions instead of trying to control '
#                'everything themselves. We also\n'
#                'help employees learn by sharing a lot of information '
#                'internally, including through memos\n'
#                'where they can comment and ask questions. It takes an '
#                'unusually responsible person to',
#                'ions. It takes an unusually responsible person to\n'
#                'thrive on this level of freedom — someone who’s '
#                'self-motivated, self-aware and\n'
#                'self-disciplined, who doesn’t wait to be told what to do and '
#                'picks up the trash like they would\n'
#                'at home. That said, context not control should not be confused '
#                'with hands-off management.\n'
#                'Managers need to be involved in the work being done around '
#                'them, and actively coach their\n'
#                'teams. They may also have to step in when someone is about to '
#                'make a decision that is',
#                'when someone is about to make a decision that is\n'
#                'unethical or could materially harm Netflix, during a crisis or '
#                'if a new team member lacks the\n'
#                'full context.\n'
#                'We avoid decision-making by committee, which tends to slow '
#                'companies down and\n'
#                'undermine accountability. For every significant decision, we '
#                'identify an informed captain\n'
#                'who’s responsible for making a judgment call on the right way '
#                'ahead. Then different teams,',
#                'all on the right way ahead. Then different teams,\n'
#                'each led by their own informed captain, implement the '
#                'decision. This highly aligned and\n'
#                'loosely coupled approach gives teams the freedom to move '
#                'quickly and operate\n'
#                'independently, while ensuring responsibility for the outcome.\n'
#                'We’ve learned that the best ideas can come from anywhere, '
#                'which is why we expect informed\n'
#                'captains to seek out different opinions and listen to people '
#                'at every level. We call this farming',
#                'en to people at every level. We call this farming\n'
#                'for dissent. Of course, not all opinions are created equal — '
#                'and with 10,000-plus employees,\n'
#                'it’s impractical for everyone to weigh in on most decisions '
#                '(this memo being an exception). So\n'
#                'on an important creative decision, for example, the opinion of '
#                'someone working in TV, film or\n'
#                'games will carry more weight than an engineer, and vice versa '
#                'when it comes to our product',
#                'neer, and vice versa when it comes to our product\n'
#                'or technology. After a decision is made, we expect everyone, '
#                'including the people who argued\n'
#                'for a different approach, to disagree and commit. This helps '
#                'ensure the outcome is as\n'
#                'successful as possible. Afterwards, when the impact is clear, '
#                'the informed captain should\n'
#                'reflect on their choices — what worked and what didn’t — so '
#                'everyone can learn how to do\n'
#                'better next time.',
#                'so everyone can learn how to do\n'
#                'better next time.\n'
#                'Launching a game, TV show or film, running a marketing '
#                'campaign, managing compensation\n'
#                'and closing a quarter all take process. And companies need '
#                'strict rules against things like\n'
#                'harassment, marginalizing colleagues, leaking company '
#                'information, or insider trading. But we\n'
#                'work hard to keep rules at Netflix to a minimum and ensure any '
#                'process is good (simple,',
#                'a minimum and ensure any process is good (simple,\n'
#                'efficient, impactful). Our vacation policy, for example, is '
#                'two words: “Take vacation.” And our\n'
#                'expenses policy is just five words: “Act in Netflix’s best '
#                'interests.” This (almost) no rules rule\n'
#                'gives employees the freedom to exercise their judgment. It '
#                'also prevents the process creep\n'
#                'that typically happens when companies grow and try to dummy '
#                'proof their organizations —\n'
#                'stifling creativity and making it harder for businesses to '
#                'adapt.',
#                'ity and making it harder for businesses to adapt.\n'
#                'You might think that this kind of freedom would lead to chaos. '
#                'In reality, while we’ve had our\n'
#                'fair share of failures — and a few people have taken advantage '
#                'of our culture in bad ways —\n'
#                'our emphasis on individual autonomy has created an extremely '
#                'successful business, with\n'
#                'many opportunities for employees to develop and grow. In '
#                'entertainment and technology, our',
#                'op and grow. In entertainment and technology, our\n'
#                'biggest threat is a lack of creativity, adaptability and '
#                'innovation. It’s why trying to minimize\n'
#                'rules and processes (rather than errors) — while giving people '
#                'the freedom to use their own\n'
#                'judgment and learn from their mistakes — is a far superior '
#                'recipe for long-term success.\n'
#                'UNCOMFORTABLY EXCITING\n'
#                'Netflix is programming for well over half a billion\n'
#                '2 people globally — something no other',
#                'a billion\n'
#                '2 people globally — something no other\n'
#                'entertainment company has ever done before. Success requires '
#                'us to be bold and ambitious,\n'
#                'to think differently, experiment and adapt (often quickly). '
#                'This is true whether we’re designing\n'
#                'a new product feature, working to improve our recommendations, '
#                'developing a marketing\n'
#                'campaign or creating a TV show or game. Many people will be '
#                'happier at companies that are',
#                'Many people will be happier at companies that are\n'
#                'more stable or take fewer risks. Netflix works best if you '
#                'value experimentation, enjoy the\n'
#                'uncomfortable excitement of a new or challenging project and '
#                'have the resilience to thrive in\n'
#                'this environment.\n'
#                'ARTISTIC EXPRESSION\n'
#                'Representation matters. Our members come from many different '
#                'backgrounds and cultures,\n'
#                'and they want to see a wide variety of stories and people on '
#                'screen. This diversity is',
#                'f stories and people on screen. This diversity is\n'
#                'wonderful and it can create real tension since we all have '
#                'such different views about what’s\n'
#                'acceptable — and what’s harmful — on TV. While every show, '
#                'film or game is different, we\n'
#                'approach them with the same set of principles: we support the '
#                'artistic expression of the\n'
#                'creators we choose to work with; we program for a wide variety '
#                'of audiences, cultures and',
#                'ram for a wide variety of audiences, cultures and\n'
#                'tastes; and we provide ratings, content advisories and '
#                'parental controls in multiple languages\n'
#                'to help members choose what to watch or play. As employees, we '
#                'support these principles,\n'
#                'even if some stories run counter to our personal values. And '
#                'we understand that, depending\n'
#                '2 As of Q1 2024 ~260 million households subscribe to Netflix. '
#                'Assuming ~2 people per household —\n'
#                'which is conservative — that means our audience is over 500M.',
#                'servative — that means our audience is over 500M.\n'
#                'on our roles, we may need to work on TV shows, films or games '
#                'we perceive to be harmful. If\n'
#                'you’d find it hard to support the breadth of our slate, '
#                'Netflix is probably not the best place for\n'
#                'you.\n'
#                'GREAT AND ALWAYS BETTER\n'
#                'Netflix has come a long way since we mailed our first DVD in '
#                "1998. But we're nowhere close\n"
#                'to where we want to be in the future. It’s why we care so much '
#                'about the Dream Team, putting',
#                'why we care so much about the Dream Team, putting\n'
#                'people over process and creating an environment where everyone '
#                'feels a sense of\n'
#                'responsibility to make us better. We believe this approach is '
#                'the surest path to excellence and\n'
#                'long term success.\n'
#                'It’s also why we constantly seek to improve our culture, not '
#                'preserve it. Every new employee\n'
#                'helps shape how we work — finding new ways to accomplish more '
#                'together. This creates a',
#                'ways to accomplish more together. This creates a\n'
#                'better experience for our members, employees, creators and '
#                'partners, which in turn propels\n'
#                'our long term growth and success. It’s how we entertain the '
#                'world and build a wildly\n'
#                'successful business.\n'
#                'As he has since our first culture deck was written in 2009, '
#                'Antoine de Saint-Exupéry, the\n'
#                'author of The Little Prince, shows us the way:\n'
#                'If you want to build a ship,\n'
#                "don't drum up the people\n"
#                'to gather wood, divide the\n'
#                'work, and give orders.',
#                'to gather wood, divide the\n'
#                'work, and give orders.\n'
#                'Instead, teach them to yearn\n'
#                'for the vast and endless sea.\n'
#                '© 2024 Netflix, Inc. All rights reserved. | Last updated: June '
#                '2024 | English Version'],
#  'embeddings': None,
#  'ids': ['chunk_0',
#          'chunk_1',
#          'chunk_2',
#          'chunk_3',
#          'chunk_4',
#          'chunk_5',
#          'chunk_6',
#          'chunk_7',
#          'chunk_8',
#          'chunk_9',
#          'chunk_10',
#          'chunk_11',
#          'chunk_12',
#          'chunk_13',
#          'chunk_14',
#          'chunk_15',
#          'chunk_16',
#          'chunk_17',
#          'chunk_18',
#          'chunk_19',
#          'chunk_20',
#          'chunk_21',
#          'chunk_22',
#          'chunk_23',
#          'chunk_24',
#          'chunk_25',
#          'chunk_26',
#          'chunk_27',
#          'chunk_28',
#          'chunk_29',
#          'chunk_30',
#          'chunk_31',
#          'chunk_32',
#          'chunk_33',
#          'chunk_34'],
#  'included': ['metadatas', 'documents'],
#  'metadatas': [{'chunk_index': 0, 'source': 'netflix_culture'},
#                {'chunk_index': 1, 'source': 'netflix_culture'},
#                {'chunk_index': 2, 'source': 'netflix_culture'},
#                {'chunk_index': 3, 'source': 'netflix_culture'},
#                {'chunk_index': 4, 'source': 'netflix_culture'},
#                {'chunk_index': 5, 'source': 'netflix_culture'},
#                {'chunk_index': 6, 'source': 'netflix_culture'},
#                {'chunk_index': 7, 'source': 'netflix_culture'},
#                {'chunk_index': 8, 'source': 'netflix_culture'},
#                {'chunk_index': 9, 'source': 'netflix_culture'},
#                {'chunk_index': 10, 'source': 'netflix_culture'},
#                {'chunk_index': 11, 'source': 'netflix_culture'},
#                {'chunk_index': 12, 'source': 'netflix_culture'},
#                {'chunk_index': 13, 'source': 'netflix_culture'},
#                {'chunk_index': 14, 'source': 'netflix_culture'},
#                {'chunk_index': 15, 'source': 'netflix_culture'},
#                {'chunk_index': 16, 'source': 'netflix_culture'},
#                {'chunk_index': 17, 'source': 'netflix_culture'},
#                {'chunk_index': 18, 'source': 'netflix_culture'},
#                {'chunk_index': 19, 'source': 'netflix_culture'},
#                {'chunk_index': 20, 'source': 'netflix_culture'},
#                {'chunk_index': 21, 'source': 'netflix_culture'},
#                {'chunk_index': 22, 'source': 'netflix_culture'},
#                {'chunk_index': 23, 'source': 'netflix_culture'},
#                {'chunk_index': 24, 'source': 'netflix_culture'},
#                {'chunk_index': 25, 'source': 'netflix_culture'},
#                {'chunk_index': 26, 'source': 'netflix_culture'},
#                {'chunk_index': 27, 'source': 'netflix_culture'},
#                {'chunk_index': 28, 'source': 'netflix_culture'},
#                {'chunk_index': 29, 'source': 'netflix_culture'},
#                {'chunk_index': 30, 'source': 'netflix_culture'},
#                {'chunk_index': 31, 'source': 'netflix_culture'},
#                {'chunk_index': 32, 'source': 'netflix_culture'},
#                {'chunk_index': 33, 'source': 'netflix_culture'},
#                {'chunk_index': 34, 'source': 'netflix_culture'}],
#  'uris': None}

# %%
pprint(collection.get(include=["documents", "metadatas","embeddings"]))
# Out:
# {'data': None,
#  'documents': ['The Best Work of Our Lives\n'
#                'CULTURE MEMO\n'
#                'At Netflix, we aspire to entertain the world, thrilling '
#                'audiences everywhere. To do that, we’ve\n'
#                'developed an unusual company culture focused on excellence, '
#                'and creating an environment\n'
#                'where talented people can thrive — lifting ourselves, each '
#                'other and our audiences higher and\n'
#                'higher. This document is about that culture, which is based on '
#                'four core principles:\n'
#                '● The Dream Team: We aim only to have high performers at '
#                'Netflix — people who are',
#                'have high performers at Netflix — people who are\n'
#                'great at what they do, and even better at working together.\n'
#                '● People over Process: You get better outcomes when employees '
#                'have the information\n'
#                'and freedom to make decisions for themselves. We hire '
#                'unusually responsible people\n'
#                'who thrive on this openness and freedom.\n'
#                '● Uncomfortably Exciting: To entertain the world, we need to '
#                'be bold and ambitious.\n'
#                'That means embracing the thrill of what’s next — even when '
#                'it’s uncomfortable.',
#                'll of what’s next — even when it’s uncomfortable.\n'
#                '● Great and Always Better: We often say Netflix sucks today '
#                'compared to where we can\n'
#                'be tomorrow. We need the self-awareness to understand what '
#                'should be better, and\n'
#                'the discipline and resilience to get there.\n'
#                'While we don’t always live up to these principles, most people '
#                'who join Netflix are pleasantly\n'
#                'surprised by how great their colleagues are and the way we '
#                'empower people at every level.',
#                'are and the way we empower people at every level.\n'
#                'As our business grows and evolves, our culture (and this '
#                'document) will, too. What won’t\n'
#                'change is our focus on excellence, and our determination to '
#                'ensure that Netflix remains a\n'
#                'place where great people can do the best work of their lives. '
#                'If this sounds exciting, you’ll\n'
#                'probably love it here. But Netflix is not for everyone, so '
#                'please read on.\n'
#                'THE DREAM TEAM',
#                't for everyone, so please read on.\n'
#                'THE DREAM TEAM\n'
#                'We believe that what makes a fantastic workplace isn’t a great '
#                'office or free meals and\n'
#                'massages — although we have some nice perks. It’s the people. '
#                'Imagine working alongside\n'
#                'stunning colleagues who are great at what they do, and even '
#                'better at working together. It’s\n'
#                'why we model ourselves on a professional sports team, not a '
#                'family. Families are about\n'
#                'unconditional love. They can also be dysfunctional, as anyone '
#                'who’s watched Ozark or',
#                'e dysfunctional, as anyone who’s watched Ozark or\n'
#                'Wednesday knows. Professional sports teams, on the other hand, '
#                'focus on performance and\n'
#                'picking the right person for every position, even when that '
#                'means swapping out someone\n'
#                'they love for a better player.\n'
#                'While every member of our Dream Team has different skills, we '
#                'look for common strengths\n'
#                'that make us better together. These are the values we value:\n'
#                '● Selflessness — you are humble when searching for the best '
#                'ideas; you seek what’s',
#                'hen searching for the best ideas; you seek what’s\n'
#                'best for Netflix, not yourself or your team; you take time to '
#                'help others succeed.\n'
#                '● Judgment — you look beyond short term fixes in favor of long '
#                'term solutions; you\n'
#                'make wise decisions despite ambiguity; you use data to inform '
#                'your intuition.\n'
#                '● Candor — you willingly receive and give feedback; you are '
#                'open about what’s working\n'
#                'and what needs to improve; you admit mistakes openly and share '
#                'learnings widely.',
#                'admit mistakes openly and share learnings widely.\n'
#                '● Creativity — you welcome new ideas; you are passionate and '
#                'persistent in pursuit of\n'
#                'more innovative solutions; you value artistic expression.\n'
#                '● Courage — you are vulnerable in search for the truth; you '
#                'are willing to risk failure, or\n'
#                'challenge the status quo, in the pursuit of excellence.\n'
#                '● Inclusion — you recognize your biases and work to counteract '
#                'them; you try to ensure',
#                'es and work to counteract them; you try to ensure\n'
#                'everyone at Netflix can do their best work, whatever their '
#                'culture, identity or\n'
#                'background.\n'
#                '● Curiosity — you learn rapidly and eagerly; you are more '
#                'interested in other people’s\n'
#                'ideas than your own; you’re humble about what you don’t yet '
#                'know.\n'
#                '● Resilience — you quickly adapt to changing circumstances; '
#                'you make tough decisions\n'
#                'without agonizing or long delay; you embrace a hard challenge.',
#                'zing or long delay; you embrace a hard challenge.\n'
#                'It’s easy to talk about values and harder to live by them. We '
#                'all work hard to keep each other\n'
#                'accountable for upholding these standards, especially our '
#                'leaders, because excellence and\n'
#                'honesty go hand in hand. It’s why we invest in strong '
#                'professional relationships that build trust\n'
#                'and help people assume good intent. This, in turn, enables us '
#                'to practice extraordinary',
#                'is, in turn, enables us to practice extraordinary\n'
#                'candor — ensuring constructive feedback is part of our '
#                'everyday work (like brushing your\n'
#                'teeth). It takes courage and vulnerability to ask someone how '
#                'you could do better, or to seek\n'
#                'alternative opinions about the best way forward, and integrity '
#                'only to say things about a\n'
#                'colleague that you’re willing to share with them directly. '
#                'This is especially true when you’re',
#                'hem directly. This is especially true when you’re\n'
#                'giving feedback to someone more senior or from a different '
#                'background, or if you come from\n'
#                'a culture or company where deference is the norm. But '
#                'extraordinary candor helps us improve\n'
#                'faster as individuals and a company.\n'
#                'Since a high performer in any role is many times more '
#                'effective than the average employee,\n'
#                'our Dream Team is driven by performance — not seniority, '
#                'tenure or unconditional loyalty. It’s',
#                'seniority, tenure or unconditional loyalty. It’s\n'
#                'also why we focus on maintaining a high performance culture. '
#                'To recruit and retain stunning\n'
#                'colleagues, we pay personal top of market for the role and '
#                'location — a judgment about what\n'
#                'that person could make in a similar role at another company, '
#                'and what we would pay to keep\n'
#                'or replace them. We expect leaders to be strong developers of '
#                'talent. And to ensure they have',
#                'ong developers of talent. And to ensure they have\n'
#                'the right player at every position, we ask them to apply what '
#                'we call the “keeper test”\n'
#                '1 —\n'
#                'asking “if X wanted to leave, would I fight to keep them?” Or '
#                '“knowing everything I know\n'
#                'today, would I hire X again?” If the answer is no, we believe '
#                'it’s fairer to everyone to part ways\n'
#                'quickly.\n'
#                '1 The “keeper test” name came from our co-founder, Reed '
#                'Hastings, who remembers catching a fish as a\n'
#                'child and his dad saying, “That’s a keeper, Reed!”',
#                'hild and his dad saying, “That’s a keeper, Reed!”\n'
#                'In the abstract, the keeper test can sound scary. In reality, '
#                'we encourage everyone to speak to\n'
#                'their managers about what’s going well and what’s not on a '
#                'regular basis. This helps avoid\n'
#                'surprises. Managers also evaluate team members on their whole '
#                'record, rather than focusing\n'
#                'on the mistakes or bets that didn’t pay off. On the Dream '
#                'Team, you need people who',
#                't pay off. On the Dream Team, you need people who\n'
#                'challenge the status quo and try new things. So we stick with '
#                'employees through short-term\n'
#                'bumps.\n'
#                'No matter how brilliant someone may be, there’s no place in '
#                'our Dream Team for people who\n'
#                'don’t treat their colleagues with decency and respect. When '
#                'you have talented people who\n'
#                'work well together — trusting each other’s intentions and '
#                'respecting their differences — it\n'
#                'makes everyone more successful.\n'
#                'PEOPLE OVER PROCESS',
#                'kes everyone more successful.\n'
#                'PEOPLE OVER PROCESS\n'
#                'Many of us have worked at companies where decisions were made '
#                'top down, there was little\n'
#                'transparency and it felt hard to make a difference — or even '
#                'get basic things done. At Netflix,\n'
#                'we aim to inspire and empower more than just manage because '
#                'people can have a greater\n'
#                'impact when they’re free to make decisions about their own '
#                'work.\n'
#                'As part of this, we strive to develop good decision-making '
#                'muscles at every level of the',
#                'ood decision-making muscles at every level of the\n'
#                'company, priding ourselves on how few, not how many, decisions '
#                'senior leaders make. We\n'
#                'expect managers to practice context not control — giving their '
#                'teams the context and clarity\n'
#                'needed to make good decisions instead of trying to control '
#                'everything themselves. We also\n'
#                'help employees learn by sharing a lot of information '
#                'internally, including through memos\n'
#                'where they can comment and ask questions. It takes an '
#                'unusually responsible person to',
#                'ions. It takes an unusually responsible person to\n'
#                'thrive on this level of freedom — someone who’s '
#                'self-motivated, self-aware and\n'
#                'self-disciplined, who doesn’t wait to be told what to do and '
#                'picks up the trash like they would\n'
#                'at home. That said, context not control should not be confused '
#                'with hands-off management.\n'
#                'Managers need to be involved in the work being done around '
#                'them, and actively coach their\n'
#                'teams. They may also have to step in when someone is about to '
#                'make a decision that is',
#                'when someone is about to make a decision that is\n'
#                'unethical or could materially harm Netflix, during a crisis or '
#                'if a new team member lacks the\n'
#                'full context.\n'
#                'We avoid decision-making by committee, which tends to slow '
#                'companies down and\n'
#                'undermine accountability. For every significant decision, we '
#                'identify an informed captain\n'
#                'who’s responsible for making a judgment call on the right way '
#                'ahead. Then different teams,',
#                'all on the right way ahead. Then different teams,\n'
#                'each led by their own informed captain, implement the '
#                'decision. This highly aligned and\n'
#                'loosely coupled approach gives teams the freedom to move '
#                'quickly and operate\n'
#                'independently, while ensuring responsibility for the outcome.\n'
#                'We’ve learned that the best ideas can come from anywhere, '
#                'which is why we expect informed\n'
#                'captains to seek out different opinions and listen to people '
#                'at every level. We call this farming',
#                'en to people at every level. We call this farming\n'
#                'for dissent. Of course, not all opinions are created equal — '
#                'and with 10,000-plus employees,\n'
#                'it’s impractical for everyone to weigh in on most decisions '
#                '(this memo being an exception). So\n'
#                'on an important creative decision, for example, the opinion of '
#                'someone working in TV, film or\n'
#                'games will carry more weight than an engineer, and vice versa '
#                'when it comes to our product',
#                'neer, and vice versa when it comes to our product\n'
#                'or technology. After a decision is made, we expect everyone, '
#                'including the people who argued\n'
#                'for a different approach, to disagree and commit. This helps '
#                'ensure the outcome is as\n'
#                'successful as possible. Afterwards, when the impact is clear, '
#                'the informed captain should\n'
#                'reflect on their choices — what worked and what didn’t — so '
#                'everyone can learn how to do\n'
#                'better next time.',
#                'so everyone can learn how to do\n'
#                'better next time.\n'
#                'Launching a game, TV show or film, running a marketing '
#                'campaign, managing compensation\n'
#                'and closing a quarter all take process. And companies need '
#                'strict rules against things like\n'
#                'harassment, marginalizing colleagues, leaking company '
#                'information, or insider trading. But we\n'
#                'work hard to keep rules at Netflix to a minimum and ensure any '
#                'process is good (simple,',
#                'a minimum and ensure any process is good (simple,\n'
#                'efficient, impactful). Our vacation policy, for example, is '
#                'two words: “Take vacation.” And our\n'
#                'expenses policy is just five words: “Act in Netflix’s best '
#                'interests.” This (almost) no rules rule\n'
#                'gives employees the freedom to exercise their judgment. It '
#                'also prevents the process creep\n'
#                'that typically happens when companies grow and try to dummy '
#                'proof their organizations —\n'
#                'stifling creativity and making it harder for businesses to '
#                'adapt.',
#                'ity and making it harder for businesses to adapt.\n'
#                'You might think that this kind of freedom would lead to chaos. '
#                'In reality, while we’ve had our\n'
#                'fair share of failures — and a few people have taken advantage '
#                'of our culture in bad ways —\n'
#                'our emphasis on individual autonomy has created an extremely '
#                'successful business, with\n'
#                'many opportunities for employees to develop and grow. In '
#                'entertainment and technology, our',
#                'op and grow. In entertainment and technology, our\n'
#                'biggest threat is a lack of creativity, adaptability and '
#                'innovation. It’s why trying to minimize\n'
#                'rules and processes (rather than errors) — while giving people '
#                'the freedom to use their own\n'
#                'judgment and learn from their mistakes — is a far superior '
#                'recipe for long-term success.\n'
#                'UNCOMFORTABLY EXCITING\n'
#                'Netflix is programming for well over half a billion\n'
#                '2 people globally — something no other',
#                'a billion\n'
#                '2 people globally — something no other\n'
#                'entertainment company has ever done before. Success requires '
#                'us to be bold and ambitious,\n'
#                'to think differently, experiment and adapt (often quickly). '
#                'This is true whether we’re designing\n'
#                'a new product feature, working to improve our recommendations, '
#                'developing a marketing\n'
#                'campaign or creating a TV show or game. Many people will be '
#                'happier at companies that are',
#                'Many people will be happier at companies that are\n'
#                'more stable or take fewer risks. Netflix works best if you '
#                'value experimentation, enjoy the\n'
#                'uncomfortable excitement of a new or challenging project and '
#                'have the resilience to thrive in\n'
#                'this environment.\n'
#                'ARTISTIC EXPRESSION\n'
#                'Representation matters. Our members come from many different '
#                'backgrounds and cultures,\n'
#                'and they want to see a wide variety of stories and people on '
#                'screen. This diversity is',
#                'f stories and people on screen. This diversity is\n'
#                'wonderful and it can create real tension since we all have '
#                'such different views about what’s\n'
#                'acceptable — and what’s harmful — on TV. While every show, '
#                'film or game is different, we\n'
#                'approach them with the same set of principles: we support the '
#                'artistic expression of the\n'
#                'creators we choose to work with; we program for a wide variety '
#                'of audiences, cultures and',
#                'ram for a wide variety of audiences, cultures and\n'
#                'tastes; and we provide ratings, content advisories and '
#                'parental controls in multiple languages\n'
#                'to help members choose what to watch or play. As employees, we '
#                'support these principles,\n'
#                'even if some stories run counter to our personal values. And '
#                'we understand that, depending\n'
#                '2 As of Q1 2024 ~260 million households subscribe to Netflix. '
#                'Assuming ~2 people per household —\n'
#                'which is conservative — that means our audience is over 500M.',
#                'servative — that means our audience is over 500M.\n'
#                'on our roles, we may need to work on TV shows, films or games '
#                'we perceive to be harmful. If\n'
#                'you’d find it hard to support the breadth of our slate, '
#                'Netflix is probably not the best place for\n'
#                'you.\n'
#                'GREAT AND ALWAYS BETTER\n'
#                'Netflix has come a long way since we mailed our first DVD in '
#                "1998. But we're nowhere close\n"
#                'to where we want to be in the future. It’s why we care so much '
#                'about the Dream Team, putting',
#                'why we care so much about the Dream Team, putting\n'
#                'people over process and creating an environment where everyone '
#                'feels a sense of\n'
#                'responsibility to make us better. We believe this approach is '
#                'the surest path to excellence and\n'
#                'long term success.\n'
#                'It’s also why we constantly seek to improve our culture, not '
#                'preserve it. Every new employee\n'
#                'helps shape how we work — finding new ways to accomplish more '
#                'together. This creates a',
#                'ways to accomplish more together. This creates a\n'
#                'better experience for our members, employees, creators and '
#                'partners, which in turn propels\n'
#                'our long term growth and success. It’s how we entertain the '
#                'world and build a wildly\n'
#                'successful business.\n'
#                'As he has since our first culture deck was written in 2009, '
#                'Antoine de Saint-Exupéry, the\n'
#                'author of The Little Prince, shows us the way:\n'
#                'If you want to build a ship,\n'
#                "don't drum up the people\n"
#                'to gather wood, divide the\n'
#                'work, and give orders.',
#                'to gather wood, divide the\n'
#                'work, and give orders.\n'
#                'Instead, teach them to yearn\n'
#                'for the vast and endless sea.\n'
#                '© 2024 Netflix, Inc. All rights reserved. | Last updated: June '
#                '2024 | English Version'],
#  'embeddings': array([[ 0.03436279,  0.02084351, -0.04281616, ...,  0.02151489,
#          0.01331329, -0.05081177],
#        [ 0.0249176 ,  0.01596069, -0.00736237, ..., -0.01416779,
#         -0.02984619, -0.04388428],
#        [ 0.00179577,  0.00965881, -0.02204895, ...,  0.00836182,
#         -0.03302002, -0.01789856],
#        ...,
#        [ 0.07232666,  0.02130127, -0.0058403 , ..., -0.02732849,
#          0.02706909, -0.02603149],
#        [ 0.03616333, -0.00045371,  0.02664185, ..., -0.02166748,
#          0.00227356, -0.01322937],
#        [ 0.02729797,  0.01745605, -0.02941895, ...,  0.01679993,
#         -0.00625229, -0.03945923]], shape=(35, 1536)),
#  'ids': ['chunk_0',
#          'chunk_1',
#          'chunk_2',
#          'chunk_3',
#          'chunk_4',
#          'chunk_5',
#          'chunk_6',
#          'chunk_7',
#          'chunk_8',
#          'chunk_9',
#          'chunk_10',
#          'chunk_11',
#          'chunk_12',
#          'chunk_13',
#          'chunk_14',
#          'chunk_15',
#          'chunk_16',
#          'chunk_17',
#          'chunk_18',
#          'chunk_19',
#          'chunk_20',
#          'chunk_21',
#          'chunk_22',
#          'chunk_23',
#          'chunk_24',
#          'chunk_25',
#          'chunk_26',
#          'chunk_27',
#          'chunk_28',
#          'chunk_29',
#          'chunk_30',
#          'chunk_31',
#          'chunk_32',
#          'chunk_33',
#          'chunk_34'],
#  'included': ['documents', 'metadatas', 'embeddings'],
#  'metadatas': [{'chunk_index': 0, 'source': 'netflix_culture'},
#                {'chunk_index': 1, 'source': 'netflix_culture'},
#                {'chunk_index': 2, 'source': 'netflix_culture'},
#                {'chunk_index': 3, 'source': 'netflix_culture'},
#                {'chunk_index': 4, 'source': 'netflix_culture'},
#                {'chunk_index': 5, 'source': 'netflix_culture'},
#                {'chunk_index': 6, 'source': 'netflix_culture'},
#                {'chunk_index': 7, 'source': 'netflix_culture'},
#                {'chunk_index': 8, 'source': 'netflix_culture'},
#                {'chunk_index': 9, 'source': 'netflix_culture'},
#                {'chunk_index': 10, 'source': 'netflix_culture'},
#                {'chunk_index': 11, 'source': 'netflix_culture'},
#                {'chunk_index': 12, 'source': 'netflix_culture'},
#                {'chunk_index': 13, 'source': 'netflix_culture'},
#                {'chunk_index': 14, 'source': 'netflix_culture'},
#                {'chunk_index': 15, 'source': 'netflix_culture'},
#                {'chunk_index': 16, 'source': 'netflix_culture'},
#                {'chunk_index': 17, 'source': 'netflix_culture'},
#                {'chunk_index': 18, 'source': 'netflix_culture'},
#                {'chunk_index': 19, 'source': 'netflix_culture'},
#                {'chunk_index': 20, 'source': 'netflix_culture'},
#                {'chunk_index': 21, 'source': 'netflix_culture'},
#                {'chunk_index': 22, 'source': 'netflix_culture'},
#                {'chunk_index': 23, 'source': 'netflix_culture'},
#                {'chunk_index': 24, 'source': 'netflix_culture'},
#                {'chunk_index': 25, 'source': 'netflix_culture'},
#                {'chunk_index': 26, 'source': 'netflix_culture'},
#                {'chunk_index': 27, 'source': 'netflix_culture'},
#                {'chunk_index': 28, 'source': 'netflix_culture'},
#                {'chunk_index': 29, 'source': 'netflix_culture'},
#                {'chunk_index': 30, 'source': 'netflix_culture'},
#                {'chunk_index': 31, 'source': 'netflix_culture'},
#                {'chunk_index': 32, 'source': 'netflix_culture'},
#                {'chunk_index': 33, 'source': 'netflix_culture'},
#                {'chunk_index': 34, 'source': 'netflix_culture'}],
#  'uris': None}

# %% [markdown]
# ## Step 6: Test Retrieval

# %%
#Generate embedding for a test query
test_query = "days off"

#Embed the query using the same model we used for the chunks to ensure compatibility
#Tip: you will need to convert the query into a list before passing it in
response = client.embeddings.create(
    model = "text-embedding-3-small",
    input = [test_query]
)
query_embedding = response.data[0].embedding

#Search ChromaDB
#Tip: use collection.query()
#Tip: you will need to convert the query embedding into a list before passing it in
results = collection.query(
    query_embeddings=[query_embedding],
    n_results=3,
)

#Verify retrieval works - print which chunks were retrieved and their content
print(f"Query: {test_query}\n")
print("Retrieved Chunks: ")
for a, b in zip(results["documents"][0], results["metadatas"][0]):
    print(f"Chunk {b['chunk_index']}:\n{a}\n")
# Out:
# Query: days off
#
# Retrieved Chunks:
# Chunk 24:
# a minimum and ensure any process is good (simple,
# efficient, impactful). Our vacation policy, for example, is two words: “Take vacation.” And our
# expenses policy is just five words: “Act in Netflix’s best interests.” This (almost) no rules rule
# gives employees the freedom to exercise their judgment. It also prevents the process creep
# that typically happens when companies grow and try to dummy proof their organizations —
# stifling creativity and making it harder for businesses to adapt.
#
# Chunk 18:
# ions. It takes an unusually responsible person to
# thrive on this level of freedom — someone who’s self-motivated, self-aware and
# self-disciplined, who doesn’t wait to be told what to do and picks up the trash like they would
# at home. That said, context not control should not be confused with hands-off management.
# Managers need to be involved in the work being done around them, and actively coach their
# teams. They may also have to step in when someone is about to make a decision that is
#
# Chunk 17:
# ood decision-making muscles at every level of the
# company, priding ourselves on how few, not how many, decisions senior leaders make. We
# expect managers to practice context not control — giving their teams the context and clarity
# needed to make good decisions instead of trying to control everything themselves. We also
# help employees learn by sharing a lot of information internally, including through memos
# where they can comment and ask questions. It takes an unusually responsible person to

# %% [markdown]
# ## Step 7: Functions to Process the Conversation Turn (with RAG)

# %%
system_message = "You are a helpful assistant that answers questions based on the provided context. \
    If you don't know the answer, say you don't know. Always use all available answer to provide \
    the best answer possible. Important: DO NOT talk about any topics that are not in the provided context.\
    and only use the information in the context to answer the question. If the question is not related\
    to the context, say you don't know or that it's not in the context."

# %%
def respond_ai(message, history):
    # RAG 
    #Embed the query using the same model we used for the chunks to ensure compatibility
    client = OpenAI(api_key=OPENAI_API_KEY)
    response = client.embeddings.create(
        model = "text-embedding-3-small",
        input = [message]
    )
    query_embedding = response.data[0].embedding

    #Search ChromaDB
    results = collection.query(
        query_embeddings=[query_embedding],
        n_results=3,
    )

    # Stitch retrieved chunks together to create the context for the response
    context = "\n---\n".join(results["documents"][0])
    print("Context this turn: \n",context)

    # Update system message with context (for this conversation turn)
    system_message_enhanced = system_message + "\n\nContext:\n" + context
    # As usual
    messages = [{"role": "system", "content": system_message_enhanced}] + history + [{"role": "user", "content": message}]
    client = OpenAI(api_key=OPENAI_API_KEY)
    response = client.chat.completions.create(
        model="gpt-4.1-mini",
        messages=messages,
    )
    reply = response.choices[0].message.content
    return reply

# %%
gr.ChatInterface(fn=respond_ai).launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7861
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7861/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Context this turn:
#  zing or long delay; you embrace a hard challenge.
# It’s easy to talk about values and harder to live by them. We all work hard to keep each other
# accountable for upholding these standards, especially our leaders, because excellence and
# honesty go hand in hand. It’s why we invest in strong professional relationships that build trust
# and help people assume good intent. This, in turn, enables us to practice extraordinary
# ---
# admit mistakes openly and share learnings widely.
# ● Creativity — you welcome new ideas; you are passionate and persistent in pursuit of
# more innovative solutions; you value artistic expression.
# ● Courage — you are vulnerable in search for the truth; you are willing to risk failure, or
# challenge the status quo, in the pursuit of excellence.
# ● Inclusion — you recognize your biases and work to counteract them; you try to ensure
# ---
# hen searching for the best ideas; you seek what’s
# best for Netflix, not yourself or your team; you take time to help others succeed.
# ● Judgment — you look beyond short term fixes in favor of long term solutions; you
# make wise decisions despite ambiguity; you use data to inform your intuition.
# ● Candor — you willingly receive and give feedback; you are open about what’s working
# and what needs to improve; you admit mistakes openly and share learnings widely.

# %% [markdown]
# ## FULL RAG PIPELINE
# 1. Load
# 2. Chunk
# 3. Embed
# 4. Store
# 5. Retrieve
# 6. Augment
# 7. Generate

# %% [markdown]
# ## RAG Improvement Methods (a non-exhaustive list)
#
# ### 1. Increase n_results - Retrieve more chunks
# ```python
# results = collection.query(query_embeddings=[embedding], n_results=10)
# ```
#
# ### 2. Adjust chunk size - Larger chunks for more context
# ```python
# chunks = chunk_text(document, chunk_size=1000, overlap=100)
# ```
# ### 3. Increase overlap - More shared text between chunks
# ```python
# chunks = chunk_text(document, chunk_size=500, overlap=150)
# ```
# ### 4. Reranking - Retrieve many, rerank to pick best
# ```python
# # reranker from sentence-transformers or Cohere
# results = collection.query(query_embeddings=[embedding], n_results=20)
# reranked = reranker.rank(query, results['documents'][0])[:5]
# ```
# ### 5. Query expansion - Multiple phrasings of same question
# ```python
# queries = ["Netflix values", "company principles", "employee expectations"]
# results = collection.query(query_embeddings=embed_all(queries), n_results=5)
# ```
# ### 6. Parent-child retrieval - Match on small chunks, return parent section
# ```python
# metadata = {"chunk_id": "chunk_7", "parent_section": "THE DREAM TEAM"}
# # When chunk_7 matches, retrieve all chunks with same parent_section
# ```
# ### 7. Sliding window context - Grab neighboring chunks
# ```python
# matched_idx = 7
# context_indices = [matched_idx - 1, matched_idx, matched_idx + 1, matched_idx + 2]
# context_chunks = [chunks[i] for i in context_indices if 0 <= i < len(chunks)]
# ```
# ### 8. Metadata filtering - Filter by source, language, date before search
# ```python
# results = collection.query(
#     query_embeddings=[embedding],
#     where={"language": "es"}
# )
# ```
# ### 9. Semantic chunking - Split by meaning, not character count
# ```python
# # SemanticChunker from langchain_experimental
# chunks = semantic_splitter.split(document)
# ```
# ### 10. Hybrid search - Vector + keyword search combined
# ```python
# # bm25_search from rank_bm25 library
# vector_results = collection.query(query_embeddings=[embedding])
# keyword_results = bm25_search(query, documents)
# final_results = merge_and_dedupe(vector_results, keyword_results)
# ```
# ### 11. Proposition-based indexing - Store LLM-extracted facts alongside chunks
# ```python
# propositions = llm.extract("List key facts from this chunk", chunk)
# # Store both chunk and propositions, link them together
# ```
# ### 12. Agentic RAG - LLM decides if more retrieval needed
# ```python
# answer = llm.generate(context=chunks, query=query)
# if llm.check("Is this answer complete?", answer) == "No":
#     new_results = collection.query(query_embeddings=embed(refined_query))
# ```
